# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lenovo\onedrive\documents\projects\alt\real-estate-image-matching\venv2\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lenovo\onedrive\documents\projects\alt\real-estate-image-matching\venv2\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lenovo\onedrive\documents\projects\alt\real-estate-image-matching\venv2\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\onedrive\documents\projects\alt\real-estate-image-matching\venv2\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\onedrive\documents\projects\alt\real-estate-image-matching\venv2\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#flask_api\model.py

import torch
import torch.nn as nn
import os
import pickle
import numpy as np
from torchvision import transforms, models
from transformers import DeiTForImageClassification, CLIPModel, CLIPProcessor
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image

# Load SimCLR Model
class SimCLR(nn.Module):
    def __init__(self, base_model, out_dim):
        super(SimCLR, self).__init__()
        self.backbone = nn.Sequential(*list(base_model.children())[:-1])
        self.projection_head = nn.Sequential(
            nn.Linear(base_model.fc.in_features, 512),
            nn.ReLU(),
            nn.Linear(512, out_dim)
        )

    def forward(self, x):
        h = self.backbone(x).squeeze()
        z = self.projection_head(h)
        return h, z

def load_model(model_path, model):
    # Corrected: No 'weights_only' argument in load_state_dict
    model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
    model.eval()  # Set to evaluation mode
    return model

# Load models
def load_models():
    simclr_model_instance = SimCLR(models.resnet50(weights='ResNet50_Weights.DEFAULT'), out_dim=128)
    simclr_model = load_model('models/simclr_model.pth', simclr_model_instance)

    deit_model = DeiTForImageClassification.from_pretrained('facebook/deit-base-distilled-patch16-224', num_labels=128)
    deit_model.load_state_dict(torch.load('models/deit_model.pth', map_location=torch.device('cpu')))

    clip_model = load_model('models/clip_model.pth', CLIPModel.from_pretrained("openai/clip-vit-base-patch32"))
    
    base_cnn_model = models.resnet18(weights='ResNet18_Weights.DEFAULT')  # Load default ResNet18
    base_cnn_model.eval()  # Set to evaluation mode

    return simclr_model, deit_model, clip_model, base_cnn_model

# Image transform for non-CLIP models
def get_image_transform():
    return transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

# # Feature extraction functions
# def extract_features(model, image, model_type):
#     with torch.no_grad():
#         image_tensor = get_image_transform()(image).unsqueeze(0)
#         if model_type == 'simclr':
#             return model(image_tensor)[1]
#         elif model_type == 'deit':
#             inputs = {"pixel_values": image_tensor}
#             outputs = model(**inputs)
#             return outputs.logits
#         elif model_type == 'clip':
#             processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
#             clip_inputs = processor(images=image, return_tensors="pt")
#             image_features = model.get_image_features(**clip_inputs)
#             return image_features.cpu().numpy().reshape(1, -1)
#         elif model_type == 'base_cnn':
#             return model(image_tensor).detach().cpu().numpy()

def extract_features(model, image_tensor, model_type):
    """Extract features from the given model."""
    with torch.no_grad():
        if model_type == "cnn":
            return model(image_tensor).squeeze().cpu().numpy()
        elif model_type == "clip":
            return model.get_image_features(image_tensor).squeeze().cpu().numpy()
        elif model_type == "deit":
            return model(image_tensor).logits.squeeze().cpu().numpy()


# Load and save features
def load_features(filename):
    if os.path.exists(filename):
        with open(filename, 'rb') as f:
            features = pickle.load(f)
        print(f"Loaded features from {filename}.")
        return features
    return {}

def save_features_to_file(features, filename):
    with open(filename, 'wb') as f:
        pickle.dump(features, f)
    print(f"Features saved to {filename}.")

# Find most similar images: Eliana (original)
# def find_most_similar_image(uploaded_features, dataset_features):
#     uploaded_features = uploaded_features.reshape(1, -1)  # Ensure shape is [1, feature_dim]
#     dataset_features_array = np.array(list(dataset_features.values()))
#     dataset_features_array = dataset_features_array.reshape(dataset_features_array.shape[0], -1)

#     similarities_cosine = cosine_similarity(uploaded_features, dataset_features_array)

#     most_similar = sorted(zip(dataset_features.keys(), similarities_cosine[0]),
#                           key=lambda item: item[1], reverse=True)

#     return most_similar

#  Revised Working Attempt (by Alleina)
# def find_most_similar_image(uploaded_features, dataset_features):
#     """Find most similar images from dataset features."""
#     uploaded_features = uploaded_features.reshape(1, -1)  # Ensure query feature is [1, dim]
#     dataset_features_array = np.array(list(dataset_features.values()))
#     dataset_features_array = dataset_features_array.reshape(dataset_features_array.shape[0], -1)

#     if uploaded_features.shape[1] != dataset_features_array.shape[1]:
#         raise ValueError(
#             f"Dimension mismatch: Query features have {uploaded_features.shape[1]} dimensions, "
#             f"but dataset features have {dataset_features_array.shape[1]} dimensions."
#         )

#     similarities_cosine = cosine_similarity(uploaded_features, dataset_features_array)
#     most_similar = sorted(
#         zip(dataset_features.keys(), similarities_cosine[0]),
#         key=lambda item: item[1],
#         reverse=True,
#     )

#     return most_similar

# Removed .values() functions
# def find_most_similar_image(uploaded_features, dataset_features):
#     """Find most similar images from dataset features."""
#     uploaded_features = uploaded_features.reshape(1, -1)  # Ensure query feature is [1, dim]
#     dataset_features_array = np.array(dataset_features)  # No need for .values() on numpy arrays
#     dataset_features_array = dataset_features_array.reshape(dataset_features_array.shape[0], -1)
    
#     if uploaded_features.shape[1] != dataset_features_array.shape[1]:
#         raise ValueError(f"Feature dimension mismatch: query features {uploaded_features.shape[1]}, dataset features {dataset_features_array.shape[1]}")

#     # Calculate similarity between query and dataset features (e.g., cosine similarity)
#     similarity_scores = cosine_similarity(uploaded_features, dataset_features_array)
    
#     # Get the indices of the most similar images
#     most_similar_indices = np.argsort(similarity_scores[0])[::-1]
#     similar_images = [(dataset_features[i], similarity_scores[0][i]) for i in most_similar_indices]
    
#     return similar_images

# from sklearn.preprocessing import StandardScaler

# def find_most_similar_image(uploaded_features, dataset_features):
#     """Find most similar images from dataset features."""
#     uploaded_features = uploaded_features.reshape(1, -1)  # Ensure query feature is [1, dim]
    
#     # Check if feature dimension mismatch exists
#     if uploaded_features.shape[1] != dataset_features.shape[1]:
#         if uploaded_features.shape[1] == 512 and dataset_features.shape[1] == 768:
#             # Rescale query feature to match dataset feature dimension (768)
#             print("Rescaling query feature from 512 to 768...")
#             uploaded_features = np.resize(uploaded_features, (uploaded_features.shape[0], 768))  # Resizing query features to 768
            
#         else:
#             raise ValueError(f"Feature dimension mismatch: query features {uploaded_features.shape[1]}, dataset features {dataset_features.shape[1]}")
    
#     # Calculate similarity between query and dataset features (e.g., cosine similarity)
#     similarity_scores = cosine_similarity(uploaded_features, dataset_features)
    
#     # Get the indices of the most similar images
#     most_similar_indices = np.argsort(similarity_scores[0])[::-1]
#     similar_images = [(dataset_features[i], similarity_scores[0][i]) for i in most_similar_indices]
    
#     return similar_images

def find_most_similar_image(uploaded_features, dataset_features, image_paths):
    """Find most similar images from dataset features."""
    uploaded_features = uploaded_features.reshape(1, -1)  # Ensure query feature is [1, dim]
    
    # Check if feature dimension mismatch exists
    if uploaded_features.shape[1] != dataset_features.shape[1]:
        if uploaded_features.shape[1] == 512 and dataset_features.shape[1] == 768:
            # Rescale query feature to match dataset feature dimension (768)
            print("Rescaling query feature from 512 to 768...")
            uploaded_features = np.resize(uploaded_features, (uploaded_features.shape[0], 768))  # Resizing query features to 768
            
        else:
            raise ValueError(f"Feature dimension mismatch: query features {uploaded_features.shape[1]}, dataset features {dataset_features.shape[1]}")
    
    # Calculate similarity between query and dataset features (e.g., cosine similarity)
    similarity_scores = cosine_similarity(uploaded_features, dataset_features)
    
    # Get the indices of the most similar images
    most_similar_indices = np.argsort(similarity_scores[0])[::-1]
    similar_images = [(image_paths[i], similarity_scores[0][i]) for i in most_similar_indices]
    
    return similar_images




# Load dataset features
def load_dataset_features(image_folder, model, model_type, feature_file):
    features = load_features(feature_file)
    if features:
        return features  # Skip extraction if features are already loaded

    features = {}
    img_files = [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png'))]

    print(f"Loading features for {len(img_files)} images...")
    
    for img_file in img_files:
        img_path = os.path.join(image_folder, img_file)
        image = Image.open(img_path).convert("RGB")
        feature = extract_features(model, image, model_type)
        features[img_path] = feature

    save_features_to_file(features, feature_file)
    return features

# %%
import os
import csv
import pickle
from PIL import Image
# from ImageMatcher import load_models, find_most_similar_image, get_image_transform, extract_features

# %%
# Paths
QUERY_IMAGE_PATH = r"C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\evaluation\image-matching\query\listing_1_image_1.png_20240927_122438.png"  # Path to the query image
OUTPUT_FOLDER = r"output"  # Output folder for the CSV files

# %%
# Feature files
CNN_FEATURES_FILE = r'C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\image-matching\features\cnn features.pkl'
CLIP_FEATURES_FILE = r'C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\image-matching\features\clip features.pkl'
DEIT_FEATURES_FILE = r'C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\image-matching\features\deit features.pkl'

# %%
import pickle

with open(DEIT_FEATURES_FILE, "rb") as f:
    dataset_features_clip = pickle.load(f)

for k, v in dataset_features_clip.items():
    print(f"Path: {k}, Feature Shape: {v.shape}")
# Out:
# Path: C:\images\listing_1000_image_1.png_20240927_173827.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_1.png_20240927_125602.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_1.png_20240927_183330.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_2.png_20240927_125604.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_2.png_20240927_183331.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_3.png_20240927_125605.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_3.png_20240927_183333.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_4.png_20240927_183335.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_5.png_20240927_183336.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_6.png_20240927_183338.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_7.png_20240927_183339.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_100_image_8.png_20240927_183341.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_1.png_20240927_125611.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_1.png_20240927_183349.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_2.png_20240927_125612.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_2.png_20240927_183351.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_3.png_20240927_125614.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_3.png_20240927_183353.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_4.png_20240927_125615.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_4.png_20240927_183354.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_5.png_20240927_183356.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_101_image_6.png_20240927_183357.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_1.png_20240927_183406.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_10.png_20240927_183420.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_2.png_20240927_183408.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_3.png_20240927_183409.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_4.png_20240927_183411.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_5.png_20240927_183412.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_6.png_20240927_183414.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_7.png_20240927_183415.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_8.png_20240927_183417.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_102_image_9.png_20240927_183418.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_1.png_20240927_183503.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_10.png_20240927_183520.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_2.png_20240927_183506.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_3.png_20240927_183508.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_4.png_20240927_183510.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_5.png_20240927_183512.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_6.png_20240927_183514.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_7.png_20240927_183515.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_8.png_20240927_183517.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_103_image_9.png_20240927_183519.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_1.png_20240927_125637.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_1.png_20240927_183529.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_2.png_20240927_125639.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_2.png_20240927_183531.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_3.png_20240927_125640.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_3.png_20240927_183533.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_4.png_20240927_183534.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_104_image_5.png_20240927_183536.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_105_image_1.png_20240927_125647.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_105_image_1.png_20240927_183654.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_105_image_2.png_20240927_125649.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_1.png_20240927_125657.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_1.png_20240927_183738.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_10.png_20240927_125710.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_2.png_20240927_125658.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_2.png_20240927_183739.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_3.png_20240927_125700.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_3.png_20240927_183741.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_4.png_20240927_125701.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_4.png_20240927_183742.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_5.png_20240927_125703.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_5.png_20240927_183744.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_6.png_20240927_125704.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_6.png_20240927_183745.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_7.png_20240927_125706.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_7.png_20240927_183747.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_8.png_20240927_125707.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_106_image_9.png_20240927_125709.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_1.png_20240927_125751.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_1.png_20240927_183753.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_10.png_20240927_125807.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_2.png_20240927_125754.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_2.png_20240927_183754.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_3.png_20240927_125755.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_3.png_20240927_183756.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_4.png_20240927_125757.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_4.png_20240927_183757.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_5.png_20240927_125758.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_5.png_20240927_183759.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_6.png_20240927_125800.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_6.png_20240927_183800.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_7.png_20240927_125802.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_7.png_20240927_183802.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_8.png_20240927_125803.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_107_image_9.png_20240927_125805.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_108_image_1.png_20240927_125814.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_108_image_2.png_20240927_183809.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_108_image_3.png_20240927_183811.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_109_image_1.png_20240927_125820.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_109_image_1.png_20240927_183817.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_109_image_2.png_20240927_125822.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_109_image_2.png_20240927_183818.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_109_image_3.png_20240927_183820.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_109_image_4.png_20240927_183821.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_1.png_20240927_122623.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_1.png_20240927_175729.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_2.png_20240927_122624.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_2.png_20240927_175731.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_3.png_20240927_122626.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_3.png_20240927_175732.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_4.png_20240927_122628.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_4.png_20240927_175734.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_5.png_20240927_122629.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_5.png_20240927_175735.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_6.png_20240927_122631.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_6.png_20240927_175737.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_7.png_20240927_175738.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_8.png_20240927_175740.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_10_image_9.png_20240927_175741.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_1.png_20240927_125829.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_1.png_20240927_183827.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_10.png_20240927_125843.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_2.png_20240927_125830.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_2.png_20240927_183829.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_3.png_20240927_125832.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_3.png_20240927_183831.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_4.png_20240927_125834.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_4.png_20240927_183832.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_5.png_20240927_125835.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_5.png_20240927_183834.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_6.png_20240927_125837.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_7.png_20240927_125838.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_8.png_20240927_125840.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_110_image_9.png_20240927_125841.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_111_image_1.png_20240927_125851.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_111_image_1.png_20240927_183950.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_111_image_2.png_20240927_125852.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_111_image_2.png_20240927_183953.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_111_image_3.png_20240927_183955.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_111_image_4.png_20240927_183957.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_111_image_5.png_20240927_183958.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_112_image_1.png_20240927_125859.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_112_image_1.png_20240927_184004.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_112_image_2.png_20240927_125900.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_113_image_1.png_20240927_125907.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_113_image_1.png_20240927_184009.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_114_image_1.png_20240927_125914.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_114_image_1.png_20240927_184017.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_114_image_2.png_20240927_184018.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_114_image_3.png_20240927_184020.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_114_image_4.png_20240927_184022.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_114_image_5.png_20240927_184023.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_114_image_6.png_20240927_184025.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_1.png_20240927_125919.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_1.png_20240927_184031.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_10.png_20240927_125933.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_2.png_20240927_125921.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_3.png_20240927_125922.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_3.png_20240927_184034.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_4.png_20240927_125924.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_4.png_20240927_184036.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_5.png_20240927_125925.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_5.png_20240927_184038.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_6.png_20240927_125927.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_6.png_20240927_184039.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_7.png_20240927_125928.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_7.png_20240927_184041.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_8.png_20240927_125930.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_115_image_9.png_20240927_125931.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_1.png_20240927_125938.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_1.png_20240927_184047.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_2.png_20240927_184049.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_3.png_20240927_184050.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_4.png_20240927_184052.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_5.png_20240927_184054.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_6.png_20240927_184055.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_7.png_20240927_184057.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_116_image_8.png_20240927_184058.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_1.png_20240927_125943.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_1.png_20240927_184105.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_10.png_20240927_125958.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_2.png_20240927_125945.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_2.png_20240927_184107.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_3.png_20240927_125946.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_3.png_20240927_184108.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_4.png_20240927_125948.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_4.png_20240927_184110.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_5.png_20240927_125950.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_5.png_20240927_184112.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_6.png_20240927_125951.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_6.png_20240927_184113.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_7.png_20240927_125953.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_8.png_20240927_125954.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_117_image_9.png_20240927_125956.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_118_image_1.png_20240927_130004.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_118_image_1.png_20240927_184121.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_118_image_2.png_20240927_184122.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_118_image_3.png_20240927_184124.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_1.png_20240927_130009.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_1.png_20240927_184131.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_2.png_20240927_130011.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_2.png_20240927_184132.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_3.png_20240927_130012.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_3.png_20240927_184134.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_4.png_20240927_130014.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_4.png_20240927_184135.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_5.png_20240927_130016.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_5.png_20240927_184137.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_6.png_20240927_184138.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_119_image_7.png_20240927_184140.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_1.png_20240927_122636.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_1.png_20240927_175748.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_2.png_20240927_175750.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_3.png_20240927_175751.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_4.png_20240927_175753.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_5.png_20240927_175754.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_6.png_20240927_175756.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_11_image_7.png_20240927_175758.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_1.png_20240927_130026.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_1.png_20240927_184221.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_2.png_20240927_130028.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_2.png_20240927_184223.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_3.png_20240927_130029.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_3.png_20240927_184224.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_4.png_20240927_130031.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_4.png_20240927_184226.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_5.png_20240927_130033.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_5.png_20240927_184227.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_6.png_20240927_184229.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_7.png_20240927_184230.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_8.png_20240927_184232.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_120_image_9.png_20240927_184233.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_1.png_20240927_130040.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_1.png_20240927_184240.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_2.png_20240927_184241.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_3.png_20240927_184243.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_4.png_20240927_184244.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_5.png_20240927_184246.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_6.png_20240927_184247.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_121_image_7.png_20240927_184249.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_1.png_20240927_130046.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_1.png_20240927_184255.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_2.png_20240927_130048.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_2.png_20240927_184257.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_3.png_20240927_130049.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_3.png_20240927_184258.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_4.png_20240927_130051.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_4.png_20240927_184300.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_5.png_20240927_130052.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_5.png_20240927_184301.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_6.png_20240927_184303.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_122_image_7.png_20240927_184305.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_1.png_20240927_130058.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_1.png_20240927_184312.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_2.png_20240927_130100.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_2.png_20240927_184313.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_3.png_20240927_130102.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_4.png_20240927_130103.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_5.png_20240927_130105.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_123_image_6.png_20240927_130106.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_1.png_20240927_130113.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_1.png_20240927_184322.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_10.png_20240927_130126.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_2.png_20240927_130114.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_2.png_20240927_184323.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_3.png_20240927_130116.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_3.png_20240927_184325.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_4.png_20240927_130117.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_4.png_20240927_184327.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_5.png_20240927_130119.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_6.png_20240927_130120.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_7.png_20240927_130122.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_8.png_20240927_130123.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_124_image_9.png_20240927_130125.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_1.png_20240927_130133.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_1.png_20240927_184333.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_2.png_20240927_130134.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_2.png_20240927_184334.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_3.png_20240927_130136.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_3.png_20240927_184336.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_4.png_20240927_130137.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_4.png_20240927_184337.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_5.png_20240927_130139.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_5.png_20240927_184339.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_6.png_20240927_130140.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_6.png_20240927_184340.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_7.png_20240927_130141.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_125_image_8.png_20240927_130143.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_126_image_1.png_20240927_130148.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_126_image_1.png_20240927_184348.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_126_image_2.png_20240927_184349.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_126_image_3.png_20240927_184351.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_127_image_1.png_20240927_130153.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_127_image_1.png_20240927_184401.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_127_image_2.png_20240927_184402.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_1.png_20240927_130159.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_1.png_20240927_184408.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_10.png_20240927_130213.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_2.png_20240927_130201.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_2.png_20240927_184410.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_3.png_20240927_130202.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_3.png_20240927_184411.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_4.png_20240927_130204.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_4.png_20240927_184413.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_5.png_20240927_130205.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_5.png_20240927_184414.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_6.png_20240927_130207.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_6.png_20240927_184416.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_7.png_20240927_130208.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_8.png_20240927_130210.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_128_image_9.png_20240927_130212.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_1.png_20240927_130220.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_1.png_20240927_184423.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_10.png_20240927_130233.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_2.png_20240927_130221.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_2.png_20240927_184424.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_3.png_20240927_130222.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_3.png_20240927_184426.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_4.png_20240927_130224.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_4.png_20240927_184427.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_5.png_20240927_130225.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_5.png_20240927_184429.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_6.png_20240927_130227.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_7.png_20240927_130228.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_8.png_20240927_130230.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_129_image_9.png_20240927_130231.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_1.png_20240927_122642.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_1.png_20240927_175804.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_2.png_20240927_122644.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_2.png_20240927_175805.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_3.png_20240927_122645.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_3.png_20240927_175807.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_4.png_20240927_175808.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_5.png_20240927_175810.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_12_image_6.png_20240927_175811.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_1.png_20240927_130239.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_1.png_20240927_184435.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_2.png_20240927_130240.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_2.png_20240927_184437.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_3.png_20240927_130242.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_3.png_20240927_184438.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_4.png_20240927_130243.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_4.png_20240927_184439.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_5.png_20240927_130245.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_130_image_6.png_20240927_130247.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_1.png_20240927_130256.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_1.png_20240927_184447.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_2.png_20240927_130258.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_2.png_20240927_184449.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_3.png_20240927_184450.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_4.png_20240927_184452.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_5.png_20240927_184453.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_6.png_20240927_184455.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_7.png_20240927_184457.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_131_image_8.png_20240927_184458.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_1.png_20240927_130303.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_1.png_20240927_184539.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_10.png_20240927_184555.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_2.png_20240927_130305.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_2.png_20240927_184543.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_3.png_20240927_130306.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_3.png_20240927_184544.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_4.png_20240927_130308.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_4.png_20240927_184546.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_5.png_20240927_130309.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_5.png_20240927_184547.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_6.png_20240927_130311.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_6.png_20240927_184549.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_7.png_20240927_130313.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_7.png_20240927_184550.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_8.png_20240927_130314.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_8.png_20240927_184552.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_132_image_9.png_20240927_184554.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_1.png_20240927_130323.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_1.png_20240927_184601.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_10.png_20240927_130337.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_2.png_20240927_130324.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_2.png_20240927_184603.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_3.png_20240927_130326.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_3.png_20240927_184605.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_4.png_20240927_130328.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_4.png_20240927_184606.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_5.png_20240927_130329.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_5.png_20240927_184608.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_6.png_20240927_130331.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_7.png_20240927_130333.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_8.png_20240927_130334.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_133_image_9.png_20240927_130336.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_1.png_20240927_130346.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_1.png_20240927_184615.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_2.png_20240927_130347.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_2.png_20240927_184617.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_3.png_20240927_130349.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_3.png_20240927_184618.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_4.png_20240927_130350.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_4.png_20240927_184620.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_5.png_20240927_130352.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_5.png_20240927_184621.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_6.png_20240927_130354.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_134_image_7.png_20240927_130355.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_1.png_20240927_130401.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_1.png_20240927_184631.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_2.png_20240927_130403.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_2.png_20240927_184633.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_3.png_20240927_130405.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_3.png_20240927_184634.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_4.png_20240927_130406.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_4.png_20240927_184635.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_5.png_20240927_130408.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_5.png_20240927_184637.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_135_image_6.png_20240927_184638.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_1.png_20240927_130417.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_1.png_20240927_184645.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_2.png_20240927_184646.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_3.png_20240927_184648.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_4.png_20240927_184649.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_5.png_20240927_184651.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_6.png_20240927_184652.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_136_image_7.png_20240927_184654.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_1.png_20240927_130423.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_1.png_20240927_184700.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_10.png_20240927_184714.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_2.png_20240927_130425.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_2.png_20240927_184702.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_3.png_20240927_130426.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_3.png_20240927_184703.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_4.png_20240927_130428.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_4.png_20240927_184705.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_5.png_20240927_130429.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_5.png_20240927_184706.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_6.png_20240927_130431.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_6.png_20240927_184708.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_7.png_20240927_130432.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_7.png_20240927_184710.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_8.png_20240927_130434.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_8.png_20240927_184711.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_137_image_9.png_20240927_184713.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_1.png_20240927_130440.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_1.png_20240927_184719.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_2.png_20240927_130442.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_3.png_20240927_130444.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_4.png_20240927_130445.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_5.png_20240927_130447.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_6.png_20240927_130448.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_7.png_20240927_130450.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_8.png_20240927_130451.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_138_image_9.png_20240927_130453.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_139_image_1.png_20240927_130457.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_139_image_1.png_20240927_184727.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_139_image_2.png_20240927_184729.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_139_image_3.png_20240927_184730.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_139_image_4.png_20240927_184732.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_13_image_1.png_20240927_122651.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_13_image_1.png_20240927_175818.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_13_image_2.png_20240927_175819.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_13_image_3.png_20240927_175821.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_13_image_4.png_20240927_175822.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_1.png_20240927_130503.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_1.png_20240927_184738.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_2.png_20240927_130504.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_2.png_20240927_184740.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_3.png_20240927_130506.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_3.png_20240927_184741.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_4.png_20240927_130508.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_4.png_20240927_184743.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_5.png_20240927_130509.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_5.png_20240927_184744.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_6.png_20240927_130511.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_6.png_20240927_184746.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_7.png_20240927_130513.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_140_image_8.png_20240927_130514.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_1.png_20240927_130521.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_1.png_20240927_184903.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_10.png_20240927_184918.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_2.png_20240927_130522.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_2.png_20240927_184906.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_3.png_20240927_130524.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_3.png_20240927_184908.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_4.png_20240927_130525.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_4.png_20240927_184909.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_5.png_20240927_184911.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_6.png_20240927_184912.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_7.png_20240927_184914.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_8.png_20240927_184915.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_141_image_9.png_20240927_184917.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_142_image_1.png_20240927_130537.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_142_image_1.png_20240927_185001.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_142_image_2.png_20240927_130538.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_142_image_2.png_20240927_185004.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_142_image_3.png_20240927_130540.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_142_image_3.png_20240927_185006.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_142_image_4.png_20240927_185007.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_1.png_20240927_130546.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_1.png_20240927_185014.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_2.png_20240927_130548.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_2.png_20240927_185016.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_3.png_20240927_130550.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_3.png_20240927_185017.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_4.png_20240927_130551.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_4.png_20240927_185019.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_5.png_20240927_130553.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_5.png_20240927_185020.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_143_image_6.png_20240927_130555.png, Feature Shape: torch.Size([1, 128])
# ...
# Path: C:\images\listing_971_image_5.png_20240927_173020.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_972_image_1.png_20240927_173028.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_972_image_2.png_20240927_173030.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_972_image_3.png_20240927_173032.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_973_image_1.png_20240927_173038.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_973_image_2.png_20240927_173040.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_973_image_3.png_20240927_173042.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_973_image_4.png_20240927_173044.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_973_image_5.png_20240927_173045.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_974_image_1.png_20240927_173052.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_974_image_2.png_20240927_173054.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_974_image_3.png_20240927_173056.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_974_image_4.png_20240927_173058.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_1.png_20240927_173104.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_10.png_20240927_173120.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_2.png_20240927_173106.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_3.png_20240927_173108.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_4.png_20240927_173109.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_5.png_20240927_173111.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_6.png_20240927_173113.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_7.png_20240927_173114.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_8.png_20240927_173116.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_975_image_9.png_20240927_173118.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_976_image_1.png_20240927_173125.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_977_image_1.png_20240927_173132.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_977_image_2.png_20240927_173134.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_977_image_3.png_20240927_173136.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_977_image_4.png_20240927_173138.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_977_image_5.png_20240927_173140.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_977_image_6.png_20240927_173142.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_977_image_7.png_20240927_173144.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_1.png_20240927_173226.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_2.png_20240927_173227.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_3.png_20240927_173229.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_4.png_20240927_173231.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_5.png_20240927_173233.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_6.png_20240927_173234.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_7.png_20240927_173236.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_978_image_8.png_20240927_173238.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_979_image_1.png_20240927_173244.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_979_image_2.png_20240927_173246.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_97_image_1.png_20240927_125328.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_97_image_1.png_20240927_183302.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_97_image_2.png_20240927_125330.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_97_image_2.png_20240927_183304.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_97_image_3.png_20240927_183305.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_97_image_4.png_20240927_183307.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_980_image_1.png_20240927_173253.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_980_image_2.png_20240927_173255.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_981_image_1.png_20240927_173300.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_981_image_2.png_20240927_173302.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_981_image_3.png_20240927_173304.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_982_image_1.png_20240927_173312.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_982_image_2.png_20240927_173313.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_982_image_3.png_20240927_173315.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_982_image_4.png_20240927_173317.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_982_image_5.png_20240927_173319.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_982_image_6.png_20240927_173321.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_983_image_1.png_20240927_173328.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_983_image_2.png_20240927_173329.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_983_image_3.png_20240927_173331.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_983_image_4.png_20240927_173333.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_983_image_5.png_20240927_173335.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_983_image_6.png_20240927_173336.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_983_image_7.png_20240927_173338.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_1.png_20240927_173345.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_10.png_20240927_173403.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_2.png_20240927_173347.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_3.png_20240927_173348.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_4.png_20240927_173351.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_5.png_20240927_173353.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_6.png_20240927_173355.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_7.png_20240927_173357.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_8.png_20240927_173359.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_984_image_9.png_20240927_173401.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_985_image_1.png_20240927_173409.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_985_image_2.png_20240927_173411.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_985_image_3.png_20240927_173413.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_985_image_4.png_20240927_173414.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_985_image_5.png_20240927_173416.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_985_image_6.png_20240927_173418.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_985_image_7.png_20240927_173420.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_986_image_1.png_20240927_173426.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_987_image_1.png_20240927_173431.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_988_image_1.png_20240927_173438.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_988_image_2.png_20240927_173440.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_989_image_1.png_20240927_173447.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_989_image_2.png_20240927_173449.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_989_image_3.png_20240927_173451.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_989_image_4.png_20240927_173453.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_989_image_5.png_20240927_173454.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_989_image_6.png_20240927_173456.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_989_image_7.png_20240927_173458.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_98_image_1.png_20240927_183313.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_98_image_2.png_20240927_183315.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_98_image_3.png_20240927_183316.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_98_image_4.png_20240927_183318.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_1.png_20240927_173505.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_2.png_20240927_173507.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_3.png_20240927_173508.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_4.png_20240927_173511.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_5.png_20240927_173512.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_6.png_20240927_173514.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_7.png_20240927_173516.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_990_image_8.png_20240927_173518.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_991_image_1.png_20240927_173523.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_992_image_1.png_20240927_173530.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_993_image_1.png_20240927_173538.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_993_image_2.png_20240927_173539.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_993_image_3.png_20240927_173541.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_993_image_4.png_20240927_173543.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_1.png_20240927_173550.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_2.png_20240927_173552.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_3.png_20240927_173554.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_4.png_20240927_173556.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_5.png_20240927_173557.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_6.png_20240927_173559.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_7.png_20240927_173601.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_994_image_8.png_20240927_173603.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_1.png_20240927_173610.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_10.png_20240927_173626.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_2.png_20240927_173612.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_3.png_20240927_173614.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_4.png_20240927_173616.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_5.png_20240927_173618.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_6.png_20240927_173619.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_7.png_20240927_173621.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_8.png_20240927_173623.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_995_image_9.png_20240927_173624.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_996_image_1.png_20240927_173632.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_996_image_2.png_20240927_173634.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_996_image_3.png_20240927_173636.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_1.png_20240927_173643.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_2.png_20240927_173644.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_3.png_20240927_173646.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_4.png_20240927_173647.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_5.png_20240927_173649.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_6.png_20240927_173650.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_7.png_20240927_173651.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_8.png_20240927_173653.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_997_image_9.png_20240927_173655.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_998_image_1.png_20240927_173735.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_998_image_2.png_20240927_173736.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_998_image_3.png_20240927_173738.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_999_image_1.png_20240927_173820.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_1.png_20240927_125540.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_1.png_20240927_183323.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_10.png_20240927_125556.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_2.png_20240927_125544.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_3.png_20240927_125545.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_4.png_20240927_125547.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_5.png_20240927_125548.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_6.png_20240927_125550.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_7.png_20240927_125552.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_8.png_20240927_125553.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_99_image_9.png_20240927_125555.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_1.png_20240927_122617.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_1.png_20240927_175711.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_2.png_20240927_175714.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_3.png_20240927_175716.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_4.png_20240927_175717.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_5.png_20240927_175718.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_6.png_20240927_175720.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_7.png_20240927_175721.png, Feature Shape: torch.Size([1, 128])
# Path: C:\images\listing_9_image_8.png_20240927_175723.png, Feature Shape: torch.Size([1, 128])

# %%
from sklearn.decomposition import PCA
import numpy as np

def reshape_features(features, expected_dim):
    features = np.array(features)
    print(f"Features shape before reshape: {features.shape}")

    # Handle 3D array by removing the second dimension (e.g., (8158, 1, 1000) -> (8158, 1000))
    if len(features.shape) == 3:
        features = features.squeeze(axis=1)

    # If the features are 1D (like in the case of query image features), reshape to 2D
    if len(features.shape) == 1:
        features = features.reshape(1, -1)
    
    # If features are 2D but have an unexpected second dimension (e.g., (1, 1000) -> reshape it to (1, 1000))
    elif len(features.shape) == 2 and features.shape[1] != expected_dim:
        features = features.reshape(features.shape[0], -1)

    # If the features' dimension is larger than expected (e.g., from 768 to 512 for CLIP), apply PCA to reduce the dimensionality
    if features.shape[1] > expected_dim:
        print(f"Reducing features from {features.shape[1]} to {expected_dim} using PCA")
        pca = PCA(n_components=expected_dim)
        features = pca.fit_transform(features)
    
    # Check if the final shape matches the expected dimension
    if features.shape[1] != expected_dim:
        raise ValueError(f"Expected features with dimension {expected_dim}, but got {features.shape[1]}")

    print(f"Features shape after reshape: {features.shape}")
    return features

# %%
# Ensure output folder exists
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %%
def preprocess_image(image, model_type):
    """Preprocess the image based on the model type."""
    transform = get_image_transform()
    image_tensor = transform(image).unsqueeze(0)  # Add batch dimension
    if model_type == "clip":
        from transformers import CLIPProcessor
        processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
        clip_inputs = processor(images=image, return_tensors="pt")
        return clip_inputs["pixel_values"]
    return image_tensor

# %%
def load_features_from_file(feature_file):
    """Load precomputed features from a .pkl file."""
    with open(feature_file, 'rb') as f:
        features = pickle.load(f)
    return features

# %%
# def save_to_csv(filename, query_image, similar_images, similarity_scores):
#     """Save results to a CSV file."""
#     filepath = os.path.join(OUTPUT_FOLDER, filename)
#     with open(filepath, mode='w', newline='', encoding='utf-8') as csvfile:
#         writer = csv.writer(csvfile)
#         writer.writerow(["Query Image", "Similar Images", "Similarity Scores"])
#         writer.writerow([
#             query_image,
#             ", ".join(similar_images),
#             ", ".join(similarity_scores)
#         ])
#     print(f"Results saved to {filepath}")

def save_to_csv(filename, query_image, similar_images, similarity_scores):
    """Save results to a CSV file."""
    filepath = os.path.join(OUTPUT_FOLDER, filename)
    with open(filepath, mode='w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Query Image", "Similar Images", "Similarity Scores"])
        writer.writerow([
            query_image,
            ", ".join(similar_images),  # Join image paths as a single string
            ", ".join(similarity_scores)  # Join similarity scores as a single string
        ])
    print(f"Results saved to {filepath}")

# %%
from sklearn.decomposition import PCA

# %%
def main():
    # Load models (used only for extracting query image features)
    _, deit_model, clip_model, cnn_model = load_models()

    # Load query image
    query_image = Image.open(QUERY_IMAGE_PATH).convert("RGB")
    print("Query Image loaded")

    # Extract query image features
    print("\nExtracting query image features using CNN model...")
    query_features_cnn = extract_features(cnn_model, preprocess_image(query_image, "cnn"), "cnn")
    query_features_cnn = reshape_features(query_features_cnn, 1000)
    
    print("\nExtracting query image features using CLIP model...")
    query_features_clip = extract_features(clip_model, preprocess_image(query_image, "clip"), "clip")
    query_features_clip = reshape_features(query_features_clip, 512)

    print("\nExtracting query image features using DEIT model...")
    query_features_deit = extract_features(deit_model, preprocess_image(query_image, "deit"), "deit")
    query_features_deit = reshape_features(query_features_deit, 128)

    # Load precomputed dataset features
    print("\nLeading pre-computed CNN Features File...")
    dataset_features_cnn = load_features_from_file(CNN_FEATURES_FILE)
    dataset_features_cnn = reshape_features(np.array(list(dataset_features_cnn.values())), 1000)
    print("\nLeading pre-computed CLIP Features File...")
    dataset_features_clip = load_features_from_file(CLIP_FEATURES_FILE)
    dataset_features_clip = reshape_features(np.array(list(dataset_features_clip.values())), 512)

    print("\nLeading pre-computed DEIT Features File...")
    dataset_features_deit = load_features_from_file(DEIT_FEATURES_FILE)
    dataset_features_deit = reshape_features(np.array(list(dataset_features_deit.values())), 128)

    # Load image paths for dataset
    image_paths_cnn = list(dataset_features_cnn.keys())
    image_paths_clip = list(dataset_features_clip.keys())
    image_paths_deit = list(dataset_features_deit.keys())

    # Find similar images for each model
    print("Finding most similar images using CNN...")
    similar_images_cnn = find_most_similar_image(query_features_cnn, dataset_features_cnn)
    print("Finding most similar images using CLIP...")
    similar_images_clip = find_most_similar_image(query_features_clip, dataset_features_clip)
    print("Finding most similar images using DEIT...")
    similar_images_deit = find_most_similar_image(query_features_deit, dataset_features_deit)

    # Combine CLIP and DEIT results
    combined_clip_deit = similar_images_clip + similar_images_deit
    print("Combining CLIP and DEIT results...")
    combined_clip_deit = sorted(combined_clip_deit, key=lambda x: x[1], reverse=True)[:5]
    print(combined_clip_deit)

    # Prepare data for CSVs
    # def prepare_csv_data(results):
    #     similar_images = [str(img) for img, _ in results]  # Convert each image path (or object) to string
    #     similarity_scores = [f"{score:.4f}" for _, score in results]
    #     return similar_images, similarity_scores

    def prepare_csv_data(results):
        """Prepare similar images and similarity scores for CSV."""
        similar_images = [img for img, _ in results]  # Only image paths
        similarity_scores = [f"{score:.4f}" for _, score in results]  # Format similarity scores
        return similar_images, similarity_scores


    # similar_images_cnn_paths, similarity_scores_cnn = prepare_csv_data(similar_images_cnn[:5])
    # print(similar_images_cnn_paths, similarity_scores_cnn)

    # similar_images_clip_paths, similarity_scores_clip = prepare_csv_data(similar_images_clip[:5])
    # print(similar_images_clip_paths, similarity_scores_clip)

    # similar_images_deit_paths, similarity_scores_deit = prepare_csv_data(similar_images_deit[:5])
    # print(similar_images_deit_paths, similarity_scores_deit)
    
    # combined_clip_deit_paths, combined_clip_deit_scores = prepare_csv_data(combined_clip_deit)

    # Find similar images for each model
    print("Finding most similar images using CNN...")
    similar_images_cnn = find_most_similar_image(query_features_cnn, dataset_features_cnn, image_paths_cnn)
    print("Finding most similar images using CLIP...")
    similar_images_clip = find_most_similar_image(query_features_clip, dataset_features_clip, image_paths_clip)
    print("Finding most similar images using DEIT...")
    similar_images_deit = find_most_similar_image(query_features_deit, dataset_features_deit, image_paths_deit)

    # Combine CLIP and DEIT results
    combined_clip_deit = similar_images_clip + similar_images_deit
    print("Combining CLIP and DEIT results...")
    combined_clip_deit = sorted(combined_clip_deit, key=lambda x: x[1], reverse=True)[:5]
    print(combined_clip_deit)

    # Prepare data for CSVs
    similar_images_cnn_paths, similarity_scores_cnn = prepare_csv_data(similar_images_cnn[:5])
    print(similar_images_cnn_paths, similarity_scores_cnn)

    similar_images_clip_paths, similarity_scores_clip = prepare_csv_data(similar_images_clip[:5])
    print(similar_images_clip_paths, similarity_scores_clip)

    similar_images_deit_paths, similarity_scores_deit = prepare_csv_data(similar_images_deit[:5])
    print(similar_images_deit_paths, similarity_scores_deit)
    
    combined_clip_deit_paths, combined_clip_deit_scores = prepare_csv_data(combined_clip_deit)

    # Save results to separate CSV files
    save_to_csv("cnn_results.csv", QUERY_IMAGE_PATH, similar_images_cnn_paths, similarity_scores_cnn)
    save_to_csv("clip_results.csv", QUERY_IMAGE_PATH, similar_images_clip_paths, similarity_scores_clip)
    save_to_csv("deit_results.csv", QUERY_IMAGE_PATH, similar_images_deit_paths, similarity_scores_deit)
    save_to_csv("clip_deit_combined_results.csv", QUERY_IMAGE_PATH, combined_clip_deit_paths, combined_clip_deit_scores)




    # # Save results to separate CSV files
    # save_to_csv("cnn_results.csv", QUERY_IMAGE_PATH, similar_images_cnn_paths, similarity_scores_cnn)
    # save_to_csv("clip_results.csv", QUERY_IMAGE_PATH, similar_images_clip_paths, similarity_scores_clip)
    # save_to_csv("deit_results.csv", QUERY_IMAGE_PATH, similar_images_deit_paths, similarity_scores_deit)
    # save_to_csv("clip_deit_combined_results.csv", QUERY_IMAGE_PATH, combined_clip_deit_paths, combined_clip_deit_scores)

# %%
if __name__ == "__main__":
    main()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6500\238729132.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
# Some weights of DeiTForImageClassification were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-224 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6500\238729132.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   deit_model.load_state_dict(torch.load('models/deit_model.pth', map_location=torch.device('cpu')))
# Query Image loaded
#
# Extracting query image features using CNN model...
# Features shape before reshape: (1000,)
# Features shape after reshape: (1, 1000)
#
# Extracting query image features using CLIP model...
# Features shape before reshape: (512,)
# Features shape after reshape: (1, 512)
#
# Extracting query image features using DEIT model...
# Features shape before reshape: (128,)
# Features shape after reshape: (1, 128)
#
# Leading pre-computed CNN Features File...
# Features shape before reshape: (8158, 1, 1000)
# Features shape after reshape: (8158, 1000)
#
# Leading pre-computed CLIP Features File...
# Features shape before reshape: (8158, 1, 768)
# Reducing features from 768 to 512 using PCA
# Features shape after reshape: (8158, 512)
#
# Leading pre-computed DEIT Features File...
# Features shape before reshape: (8158, 1, 128)
# Features shape after reshape: (8158, 128)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[190], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[189], line 35, in main()
#      32 dataset_features_deit = reshape_features(np.array(list(dataset_features_deit.values())), 128)
#      34 # Load image paths for dataset
# ---> 35 image_paths_cnn = list(dataset_features_cnn.keys())
#      36 image_paths_clip = list(dataset_features_clip.keys())
#      37 image_paths_deit = list(dataset_features_deit.keys())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'keys'
