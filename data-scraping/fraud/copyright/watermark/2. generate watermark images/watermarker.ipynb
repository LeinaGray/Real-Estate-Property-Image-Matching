# %% [markdown]
# ## Watermarker

# %% [markdown]
# ### 1. Import Libraries

# %%
import requests
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
import random, os

# %% [markdown]
# ### 2. Extract List of Image URLs, Developers, and Logo URLs from Watermark Data CSV File

# %%
import pandas as pd

def extract_columns_from_csv(csv_path, start_index=0, end_index=None):
    """Extracts columns from a CSV file and returns them as variables, allowing for specifying start and end indices.

    Args:
        csv_path: The path to the CSV file.
        start_index: The starting index (inclusive).
        end_index: The ending index (exclusive). If None, extracts all rows.

    Returns:
        A tuple containing three variables: image_urls, developers, and logo_urls.
    """

    # Read the CSV file using pandas
    df = pd.read_csv(csv_path)

    # Extract columns and save them as variables, specifying start and end indices
    image_urls = df["Image URL"][start_index:end_index]
    developers = df["Developer"][start_index:end_index]
    logo_urls = df["Logo URL"][start_index:end_index]

    return image_urls, developers, logo_urls

# Example usage
# paste absolute path of CSV file here:
csv_path = r"C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\dataset\watermark_data.csv"
start_index = 250  # Start from the nth row (index 0 is the first row)
end_index = 501    # Extract up to the nth row (exclusive)

image_urls, developers, logo_urls = extract_columns_from_csv(csv_path, start_index, end_index)

# Print the extracted variables (optional)
print("Image URLs:")
print(image_urls.tolist())  # Print as a list

print("\nDevelopers:")
print(developers.tolist())  # Print as a list

print("\nLogo URLs:")
print(logo_urls.tolist())  # Print as a list
# Out:
# Image URLs:
# ['https://api.omh.app/store/picture/73c0d16f-4d1b-46ff-8063-aea817648ed1', 'https://api.omh.app/store/picture/f88c1b7e-9dc4-4c81-b305-9e21ef2b67d6', 'https://api.omh.app/store/picture/7a14cee8-e940-4907-9cc4-9c57d0533336', 'https://api.omh.app/store/picture/d921840f-716f-4bf1-b397-4a7eb06d545e', 'https://api.omh.app/store/picture/701d0579-0c0d-4c07-b24f-b7fe00d6dcdf', 'https://api.omh.app/store/picture/34d7b06f-6491-4a0c-99e9-41058bb16eb6', 'https://api.omh.app/store/picture/de5ec0a3-56be-41fc-b345-8d6c06a6a732', 'https://api.omh.app/store/picture/26931d28-566e-47e2-bfd1-61a28ebc2bba', 'https://api.omh.app/store/picture/fff66b22-5ecc-477e-bea6-1f6ea1233bd6', 'https://api.omh.app/store/picture/f3153fa6-1deb-4622-84ff-dea6ec8f64d4', 'https://api.omh.app/store/picture/08816d52-0234-45e6-aeb0-0ca9dc73ef1f', 'https://api.omh.app/store/picture/c325cfbe-1eb6-4355-add1-43c34e52e221', 'https://api.omh.app/store/picture/b6ab777a-a596-4d64-bd3a-101392c0a4ab', 'https://api.omh.app/store/picture/f226ad21-c986-453d-a7e8-b6d478af281f', 'https://api.omh.app/store/picture/5aa612dc-79c1-489e-81b7-1420acbf88e3', 'https://api.omh.app/store/picture/45766c45-6fe2-4e8c-ab99-e7a20a57c248', 'https://api.omh.app/store/picture/ee59bc12-1686-414e-9210-8191a917a708', 'https://api.omh.app/store/picture/1a3c461a-b16f-4f08-9ca8-5378bcce8e30', 'https://api.omh.app/store/picture/f36de1a8-3832-4dd5-aab2-788e89a8fb51', 'https://api.omh.app/store/picture/594a17c9-eff9-4943-bb74-aa9b682e9f95', 'https://api.omh.app/store/picture/a1bb47e8-a004-4456-884a-763f0680c91e', 'https://api.omh.app/store/picture/a04b242b-3fe7-435f-b182-b16ab1481b35', 'https://api.omh.app/store/picture/36a6949f-c489-4818-9d92-26b26f57e2f8', 'https://api.omh.app/store/picture/7ecbd58b-23e3-44b8-bdc5-896900fff3cf', 'https://api.omh.app/store/picture/36972eab-3621-4c9b-ba3b-73ccacf7ee55', 'https://api.omh.app/store/picture/ceb90f97-7aac-4d6d-8030-235b8a2dc300', 'https://api.omh.app/store/picture/6af26676-6182-4c3b-b37f-2e9c64af6524', 'https://api.omh.app/store/picture/e8e61595-ca8b-49c1-ab16-adf8fb8195b0', 'https://api.omh.app/store/picture/e9590dd5-d7ee-4b07-9422-891b4eca3dfc', 'https://api.omh.app/store/picture/9275b85d-b197-4c8e-a270-197aed2800b7', 'https://api.omh.app/store/picture/695f3135-3706-4800-af3d-d662051dbf09', 'https://api.omh.app/store/picture/a9c0f92e-1479-48fc-a212-e63ce9692723', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'ht ...
#
# Developers:
# ['ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'ST. Felisse Realty and Development Corporation', 'RLC Residences', 'RLC Residences', 'RLC Residences', 'RLC Residences', 'RCD Land Inc', 'RCD Land Inc', 'RCD Land Inc', 'RCD Land Inc', 'RCD Land Inc', 'RCD Land Inc', 'Primary Homes Incorporated', 'Primary Homes Incorporated', 'Primary Homes Incorporated', 'Primary Homes Incorporated', 'Primary Homes Incorporated', 'Primary Homes Incorporated', 'Primary Homes Incorporated', 'YCP Properties', 'YCP Properties', 'YCP Properties', 'YCP Properties', 'YCP Properties', 'YCP Properties', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Elanvital Enclaves', 'Elanvital Enclaves', 'Elanvital Enclaves', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'PH1 World', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'Antonio Y De Pio National Hwy, Balamban, Cebu, 6041', 'Antonio Y De Pio National Hwy, Balamban, Cebu, 6041', 'Antonio Y De Pio National Hwy, Balamban, Cebu, 6041', 'Antonio Y De Pio National Hwy, Balamban, Cebu, 6041', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Company, Inc.', 'A Brown Comp ...
#
# Logo URLs:
# ['https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/ecca5558-9aaf-4e45-b897-9bbd4c76e441', 'https://api.omh.app/store/picture/3d6b3e99-3ceb-4f9b-bb97-aab0d09e028d', 'https://api.omh.app/store/picture/3d6b3e99-3ceb-4f9b-bb97-aab0d09e028d', 'https://api.omh.app/store/picture/3d6b3e99-3ceb-4f9b-bb97-aab0d09e028d', 'https://api.omh.app/store/picture/3d6b3e99-3ceb-4f9b-bb97-aab0d09e028d', 'https://api.omh.app/store/picture/fe421b4c-3ae5-40a0-9b4b-e58947584f22', 'https://api.omh.app/store/picture/fe421b4c-3ae5-40a0-9b4b-e58947584f22', 'https://api.omh.app/store/picture/fe421b4c-3ae5-40a0-9b4b-e58947584f22', 'https://api.omh.app/store/picture/fe421b4c-3ae5-40a0-9b4b-e58947584f22', 'https://api.omh.app/store/picture/fe421b4c-3ae5-40a0-9b4b-e58947584f22', 'https://api.omh.app/store/picture/fe421b4c-3ae5-40a0-9b4b-e58947584f22', 'https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e', 'https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e', 'https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e', 'https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e', 'https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e', 'https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e', 'https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e', 'https://api.omh.app/store/picture/f0c22ede-c8ad-454e-a158-47a31d071175', 'https://api.omh.app/store/picture/f0c22ede-c8ad-454e-a158-47a31d071175', 'https://api.omh.app/store/picture/f0c22ede-c8ad-454e-a158-47a31d071175', 'https://api.omh.app/store/picture/f0c22ede-c8ad-454e-a158-47a31d071175', 'https://api.omh.app/store/picture/f0c22ede-c8ad-454e-a158-47a31d071175', 'https://api.omh.app/store/picture/f0c22ede-c8ad-454e-a158-47a31d071175', 'https://api.omh.app/store/picture/2b3afbf2-c1c4-472f-a02d-f5b5b98f402f', 'https://api.omh.app/store/picture/327981ce-032e-4656-a651-cec1d6eae854', 'https://api.omh.app/store/picture/cba7f199-d587-4e28-8f0a-60044b105688', 'https://api.omh.app/store/picture/5ee5501a-6a35-4276-a103-b358d20fc3a9', 'https://api.omh.app/store/picture/ab45f6b4-70bf-4066-bfe7-ef261e306078', 'https://api.omh.app/store/picture/d8898fa0-da61-4834-b25a-6f9c7e84d031', 'https://api.omh.app/store/picture/3e646596-47f5-4ea6-949a-a0ad6463dcbe', 'https://api.omh.app/store/picture/5f2e0500-9a78-4cf0-a2bf-20b2984c7437', 'https://api.omh.app/store/picture/51e23415-f6b9-4d2a-9b55-348a84b1ae54', 'https://api.omh.app/store/picture/9335ac44-b7f1-4be6-b060-7096fa8f5c57', 'https://api.omh.app/store/picture/23cc5af5-3433-4456-baf1-05512502d080', 'https://api.omh.app/store/picture/2762fd7c-f8a0-441c-b9b5-6d63cc1c12d7', 'https://api.omh.app/store/picture/e06b8fa1-7456-44f7-b3bb-23f4a4bbcf8b', 'https://api.omh.app/store/picture/80ac5f71-a874-4bd4-9731-03db1aba2497', 'https://api.omh.app/store/picture/ae5bbb9b-a98b-4436-9841-f63a47e1f1d9', 'https://api.omh.app/store/picture/eee00568-c37c-47e1-8ae6-aa606c188ea7', 'https://api.omh.app/store/picture/89ac4fa2-1931-4b4f-bad8-a28b3525024e', 'https://api.omh.app/store/picture/629db31b-e537-4401-9ac4-47d08a04d969', 'https://api.omh.app/store/picture/f320dc84-cc23-4223-bc5f-2e3cb4aaaac7', 'https://api.omh.app/store/picture/1e42ec81-fb00-4886-938f-1d4debaebfda', 'https://api.omh.app/store/picture/936268ac-2d97-4c34-be74-72886591e1c4', 'https://api.omh.app/store/picture/d546f23f-f74a-4ac4-8301-e411dbc9e2ed', 'ht ...

# %% [markdown]
# ### 3. Add Watermark to Property Image

# %% [markdown]
# ##### Option 1: Add Logo URL Image as Watermark in Property Image

# %%
import requests
from PIL import Image
from io import BytesIO
import random, os

def download_and_watermark_images(image_urls, logo_urls, output_dir, transparency=0.7):
    """Downloads images and adds a watermark with random placement.

    Args:
        image_urls: A list of image URLs.
        logo_urls: A list of logo URLs, each corresponding to an image in image_urls.
        output_dir: The directory to save the watermarked images.
        transparency: The transparency level for the watermark logo (0 to 1).
    """
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for index, (image_url, logo_url) in enumerate(zip(image_urls, logo_urls)):
        # Download and open each image
        image = Image.open(BytesIO(requests.get(image_url).content)).convert("RGBA")

        # Download and open the logo image, then convert it to RGBA
        logo_image = Image.open(BytesIO(requests.get(logo_url).content)).convert("RGBA")

        # Resize the logo to a suitable size (adjust as needed)
        size = random.randint(150, 400)
        logo_size = (size, size)
        logo = logo_image.resize(logo_size, Image.LANCZOS)

        # Randomly place the watermark within the image (fix for negative width)
        image_width, image_height = image.size
        watermark_width, watermark_height = logo.size
        max_x_position = image_width - watermark_width  # Maximum valid X position
        x = random.randint(0, max_x_position)  # Random X within valid range
        y = random.randint(0, image_height - watermark_height)


        # Set transparency for the logo
        logo.putalpha(int(255 * transparency))

        # Create a new image with the watermark overlay
        watermark_image = image.copy()
        watermark_image.paste(logo, (x, y), logo)  # Using logo as the transparency mask

        # Save the watermarked image in JPEG format (or PNG if transparency is required)
        watermark_filename = f"watermarked_image_{index}.jpg"
        watermark_image.convert("RGB").save(os.path.join(output_dir, watermark_filename), "JPEG")

# Example usage
test_image_urls = [
    "https://api.omh.app/store/picture/a9c0f92e-1479-48fc-a212-e63ce9692723",
    "https://api.omh.app/store/picture/695f3135-3706-4800-af3d-d662051dbf09",
    # ... more image URLs
]
test_logo_urls = [
    "https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783",
    "https://api.omh.app/store/picture/04d5d9aa-22f8-4994-b17a-8fff389af97e",
    # ... more logo URLs
]
output_dir = "watermarked_images/logo_watermark"

download_and_watermark_images(test_image_urls, test_logo_urls, output_dir)

# %% [markdown]
# ##### Option 2: Add Developer Name as Text Watermark in Property Image

# %%
import os

def get_font_paths(font_dir):
  """Gets a list of font paths from the given directory.

  Args:
    font_dir: The directory containing the font files.

  Returns:
    A list of font paths.
  """

  if not os.path.exists(font_dir):
    print(f"Error: Font directory '{font_dir}' does not exist.")
    return []

  font_files = [f for f in os.listdir(font_dir) if f.endswith(('.TTF', '.OTF'))]
  font_paths = [os.path.join(font_dir, font_file) for font_file in font_files]

  return font_paths

# Example usage:
font_dir = r"C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\fonts"
font_paths = get_font_paths(font_dir)

print(font_paths)
# Out:
# ['C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIAL.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIALBD.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIALBI.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIALI.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIALN.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIALNB.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIALNBI.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIALNI.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\ARIBLK.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\BEBASNEUE-REGULAR.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\GLECB.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\IMPACT.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\LEMONMILK.OTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-BLACK.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-BLACKITALIC.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-BOLD.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-BOLDITALIC.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-EXTRABOLD.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-EXTRABOLDITALIC.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-EXTRALIGHT.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-EXTRALIGHTITALIC.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-ITALIC.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-LIGHT.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\Real-Estate-Image-Matching\\data-scraping\\watermark-scraper\\1. scrape dataset\\fonts\\MONTSERRAT-LIGHTITALIC.TTF', 'C:\\Users\\lenovo\\OneDrive\\Documents\\PROJECTS\\ALT\\ ...

# %%
import requests
from PIL import Image, ImageDraw, ImageFont, ImageStat, ImageFilter
from io import BytesIO
import random
import os

def is_plain_region(image, x, y, width, height, threshold=10):
    """Check if a region is plain by evaluating its texture variance."""
    region = image.crop((x, y, x + width, y + height))
    blurred = region.filter(ImageFilter.GaussianBlur(radius=5))
    diff = ImageStat.Stat(region).mean[0] - ImageStat.Stat(blurred).mean[0]
    return abs(diff) < threshold


def download_and_watermark_images(start_index, image_urls, logo_names, output_dir, transparency=128, sample_size=20, max_retries=10):
    """Downloads images and adds a watermark text in a visible area."""
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for index, (image_url, logo_name) in enumerate(zip(image_urls, logo_names)):
        print(f"Processing image {index + start_index}")
        retry_count = 0
        while retry_count < max_retries:
            try:
                # Download and open each image
                image = Image.open(BytesIO(requests.get(image_url).content)).convert("RGBA")

                # Convert image to grayscale and smooth version for plain region analysis
                grayscale_image = image.convert("L")
                smoothed_image = grayscale_image.filter(ImageFilter.GaussianBlur(radius=5))

                # Load font
                min_font_size = 50
                max_font_size = 150

                # Randomly choose a font
                font_path = random.choice(font_paths)
                try:
                    font = ImageFont.truetype(font_path, 50)
                except IOError:
                    font = ImageFont.load_default()

                # Randomly choose text case
                case_option = random.choice(["upper", "lower", "title", "original"])
                if case_option == "upper":
                    logo_name = logo_name.upper()
                elif case_option == "lower":
                    logo_name = logo_name.lower()
                elif case_option == "title":
                    logo_name = logo_name.title()

                # Initialize watermark text bounding box
                text_overlay = Image.new("RGBA", image.size, (255, 255, 255, 0))
                draw = ImageDraw.Draw(text_overlay)

                # Find suitable placement
                best_x, best_y = None, None
                lowest_brightness = 255
                for _ in range(sample_size):
                    font_size = random.randint(min_font_size, max_font_size)
                    font = ImageFont.truetype(font_path, font_size)
                    text_bbox = draw.textbbox((0, 0), logo_name, font=font)
                    text_width = text_bbox[2] - text_bbox[0]
                    text_height = text_bbox[3] - text_bbox[1]

                    # Ensure font fits within the image
                    while (text_width > image.width or text_height > image.height) and font_size > min_font_size:
                        font_size -= 2
                        font = ImageFont.truetype(font_path, font_size)
                        text_bbox = draw.textbbox((0, 0), logo_name, font=font)
                        text_width = text_bbox[2] - text_bbox[0]
                        text_height = text_bbox[3] - text_bbox[1]

                    if font_size <= min_font_size:
                        print(f"Warning: Font size reached minimum limit for image {index + start_index}.")
                        break

                    # Random position
                    x = random.randint(0, image.width - text_width)
                    y = random.randint(0, image.height - text_height)

                    # Check brightness and plain region
                    crop_area = grayscale_image.crop((x, y, x + text_width, y + text_height))
                    brightness = ImageStat.Stat(crop_area).mean[0]

                    if is_plain_region(smoothed_image, x, y, text_width, text_height) and brightness < lowest_brightness:
                        lowest_brightness = brightness
                        best_x, best_y = x, y

                # Fallback position and font size
                if best_x is None or best_y is None:
                    best_x = (image.width - text_width) // 2
                    best_y = (image.height - text_height) // 2

                # Draw watermark text
                draw.text((best_x, best_y), logo_name, fill=(255, 255, 255, transparency), font=font)

                # Combine images
                watermarked_image = Image.alpha_composite(image, text_overlay)

                # Save the watermarked image
                output_path = os.path.join(output_dir, f"watermarked_image_{index + start_index}.jpg")
                watermarked_image.convert("RGB").save(output_path, "JPEG")

                print(f"Font size used: {font_size}")
                break
            except Exception as e:
                    retry_count += 1
                    print(f"Failed to process image {index + start_index} on attempt {retry_count}: {e}")
                    if retry_count >= max_retries:
                        print(f"Max retries reached for image {index + start_index}. Skipping.")

# Example usage
test_image_urls = [
    "https://api.omh.app/store/picture/a9c0f92e-1479-48fc-a212-e63ce9692723",
    "https://api.omh.app/store/picture/695f3135-3706-4800-af3d-d662051dbf09",
]
test_logo_names = ["OhMyHome", "PropertyGuru"]
output_dir = "watermarked_images/test"

download_and_watermark_images(250, image_urls, developers, output_dir)
# Out:
# Processing image 250
# Warning: Font size reached minimum limit for image 250.
# Font size used: 50
# Processing image 251
# Font size used: 62
# Processing image 252
# Font size used: 77
# Processing image 253
# Warning: Font size reached minimum limit for image 253.
# Font size used: 50
# Processing image 254
# Warning: Font size reached minimum limit for image 254.
# Font size used: 50
# Processing image 255
# Font size used: 82
# Processing image 256
# Font size used: 76
# Processing image 257
# Font size used: 52
# Processing image 258
# Warning: Font size reached minimum limit for image 258.
# Font size used: 50
# Processing image 259
# Font size used: 63
# Processing image 260
# Font size used: 91
# Processing image 261
# Font size used: 53
# Processing image 262
# Font size used: 149
# Processing image 263
# Font size used: 84
# Processing image 264
# Font size used: 109
# Processing image 265
# Font size used: 59
# Processing image 266
# Font size used: 63
# Processing image 267
# Font size used: 85
# Processing image 268
# Font size used: 112
# Processing image 269
# Warning: Font size reached minimum limit for image 269.
# Font size used: 50
# Processing image 270
# Warning: Font size reached minimum limit for image 270.
# Font size used: 50
# Processing image 271
# Font size used: 145
# Processing image 272
# Font size used: 136
# Processing image 273
# Font size used: 57
# Processing image 274
# Font size used: 66
# Processing image 275
# Font size used: 81
# Processing image 276
# Font size used: 113
# Processing image 277
# Font size used: 55
# Processing image 278
# Font size used: 54
# Processing image 279
# Warning: Font size reached minimum limit for image 279.
# Font size used: 50
# Processing image 280
# Font size used: 107
# Processing image 281
# Font size used: 104
# Processing image 282
# Font size used: 134
# Processing image 283
# Font size used: 89
# Processing image 284
# Font size used: 62
# Processing image 285
# Font size used: 56
# Processing image 286
# Font size used: 90
# Processing image 287
# Font size used: 123
# Processing image 288
# Font size used: 98
# Processing image 289
# Font size used: 111
# Processing image 290
# Font size used: 92
# Processing image 291
# Font size used: 125
# Processing image 292
# Font size used: 80
# Processing image 293
# Font size used: 72
# Processing image 294
# Font size used: 61
# Processing image 295
# Font size used: 99
# Processing image 296
# Font size used: 123
# Processing image 297
# Font size used: 110
# Processing image 298
# Warning: Font size reached minimum limit for image 298.
# Font size used: 50
# Processing image 299
# Font size used: 68
# Processing image 300
# Warning: Font size reached minimum limit for image 300.
# Font size used: 50
# Processing image 301
# Font size used: 72
# Processing image 302
# Font size used: 68
# Processing image 303
# Font size used: 95
# Processing image 304
# Warning: Font size reached minimum limit for image 304.
# Font size used: 50
# Processing image 305
# Font size used: 98
# Processing image 306
# Font size used: 93
# Processing image 307
# Font size used: 60
# Processing image 308
# Font size used: 58
# Processing image 309
# Font size used: 92
# Processing image 310
# Warning: Font size reached minimum limit for image 310.
# Font size used: 50
# Processing image 311
# Font size used: 126
# Processing image 312
# Font size used: 133
# Processing image 313
# Font size used: 125
# Processing image 314
# Font size used: 148
# Processing image 315
# Font size used: 77
# Processing image 316
# Font size used: 141
# Processing image 317
# Font size used: 88
# Processing image 318
# Font size used: 108
# Processing image 319
# Font size used: 138
# Processing image 320
# Font size used: 91
# Processing image 321
# Warning: Font size reached minimum limit for image 321.
# Font size used: 50
# Processing image 322
# Font size used: 63
# Processing image 323
# Font size used: 133
# Processing image 324
# Font size used: 84
# Processing image 325
# Font size used: 53
# Processing image 326
# Warning: Font size reached minimum limit for image 326.
# Font size used: 50
# Processing image 327
# Warning: Font size reached minimum limit for image 327.
# Font size used: 50
# Processing image 328
# Font size used: 126
# Processing image 329
# Warning: Font size reached minimum limit for image 329.
# Font size used: 50
# Processing image 330
# Font size used: 90
# Processing image 331
# Font size used: 59
# Processing image 332
# Font size used: 133
# Processing image 333
# Warning: Font size reached minimum limit for image 333.
# Font size used: 50
# Processing image 334
# Font size used: 114
# Processing image 335
# Font size used: 136
# Processing image 336
# Font size used: 136
# Processing image 337
# Font size used: 120
# Processing image 338
# Font size used: 120
# Processing image 339
# Font size used: 103
# Processing image 340
# Font size used: 67
# Processing image 341
# Font size used: 88
# Processing image 342
# Font size used: 136
# Processing image 343
# Font size used: 105
# Processing image 344
# Warning: Font size reached minimum limit for image 344.
# Font size used: 50
# Processing image 345
# Font size used: 139
# Processing image 346
# Font size used: 69
# Processing image 347
# Warning: Font size reached minimum limit for image 347.
# Font size used: 50
# Processing image 348
# Font size used: 137
# Processing image 349
# Warning: Font size reached minimum limit for image 349.
# Font size used: 50
# Processing image 350
# Font size used: 148
# Processing image 351
# Font size used: 86
# Processing image 352
# Font size used: 89
# Processing image 353
# Font size used: 73
# Processing image 354
# Font size used: 126
# Processing image 355
# Font size used: 139
# Processing image 356
# Font size used: 83
# Processing image 357
# Font size used: 77
# Processing image 358
# Font size used: 140
# Processing image 359
# Font size used: 86
# Processing image 360
# Font size used: 51
# Processing image 361
# Warning: Font size reached minimum limit for image 361.
# Font size used: 50
# Processing image 362
# Warning: Font size reached minimum limit for image 362.
# Font size used: 50
# Processing image 363
# Font size used: 88
# Processing image 364
# Font size used: 115
# Processing image 365
# Font size used: 82
# Processing image 366
# Font size used: 93
# Processing image 367
# Warning: Font size reached minimum limit for image 367.
# Font size used: 50
# Processing image 368
# Warning: Font size reached minimum limit for image 368.
# Font size used: 50
# Processing image 369
# Warning: Font size reached minimum limit for image 369.
# Font size used: 49
# Processing image 370
# Warning: Font size reached minimum limit for image 370.
# Font size used: 50
# Processing image 371
# Font size used: 64
# Processing image 372
# Warning: Font size reached minimum limit for image 372.
# Font size used: 50
# Processing image 373
# Font size used: 77
# Processing image 374
# Warning: Font size reached minimum limit for image 374.
# Font size used: 50
# Processing image 375
# Warning: Font size reached minimum limit for image 375.
# Font size used: 50
# Processing image 376
# Warning: Font size reached minimum limit for image 376.
# Font size used: 50
# Processing image 377
# Font size used: 97
# Processing image 378
# Font size used: 82
# Processing image 379
# Font size used: 92
# Processing image 380
# Font size used: 134
# Processing image 381
# Font size used: 84
# Processing image 382
# Warning: Font size reached minimum limit for image 382.
# Font size used: 50
# Processing image 383
# Font size used: 85
# Processing image 384
# Font size used: 53
# Processing image 385
# Font size used: 72
# Processing image 386
# Font size used: 80
# Processing image 387
# Font size used: 54
# Processing image 388
# Font size used: 52
# Processing image 389
# Warning: Font size reached minimum limit for image 389.
# Font size used: 50
# Processing image 390
# Font size used: 63
# Processing image 391
# Font size used: 69
# Processing image 392
# Warning: Font size reached minimum limit for image 392.
# Font size used: 49
# Processing image 393
# Warning: Font size reached minimum limit for image 393.
# Font size used: 50
# Processing image 394
# Warning: Font size reached minimum limit for image 394.
# Font size used: 49
# Processing image 395
# Warning: Font size reached minimum limit for image 395.
# Font size used: 50
# Processing image 396
# Font size used: 103
# Processing image 397
# Font size used: 102
# Processing image 398
# Warning: Font size reached minimum limit for image 398.
# Font size used: 50
# Processing image 399
# Font size used: 119
# Processing image 400
# Font size used: 115
# Processing image 401
# Font size used: 117
# Processing image 402
# Font size used: 99
# Processing image 403
# Font size used: 106
# Processing image 404
# Font size used: 55
# Processing image 405
# Font size used: 96
# Processing image 406
# Warning: Font size reached minimum limit for image 406.
# Font size used: 50
# Processing image 407
# Font size used: 57
# Processing image 408
# Font size used: 126
# Processing image 409
# Warning: Font size reached minimum limit for image 409.
# Font size used: 50
# Processing image 410
# Font size used: 55
# Processing image 411
# Font size used: 67
# Processing image 412
# Font size used: 73
# Processing image 413
# Font size used: 64
# Processing image 414
# Warning: Font size reached minimum limit for image 414.
# Font size used: 50
# Processing image 415
# Font size used: 127
# Processing image 416
# Warning: Font size reached minimum limit for image 416.
# Font size used: 50
# Processing image 417
# Font size used: 117
# Processing image 418
# Font size used: 132
# Processing image 419
# Font size used: 125
# Processing image 420
# Font size used: 143
# Processing image 421
# Warning: Font size reached minimum limit for image 421.
# Font size used: 50
# Processing image 422
# Font size used: 85
# Processing image 423
# Font size used: 139
# Processing image 424
# Font size used: 142
# Processing image 425
# Font size used: 56
# Processing image 426
# Warning: Font size reached minimum limit for image 426.
# Font size used: 50
# Processing image 427
# Font size used: 76
# Processing image 428
# Font size used: 92
# Processing image 429
# Font size used: 134
# Processing image 430
# Font size used: 77
# Processing image 431
# Font size used: 106
# Processing image 432
# Font size used: 52
# Processing image 433
# Warning: Font size reached minimum limit for image 433.
# Font size used: 50
# Processing image 434
# Font size used: 55
# Processing image 435
# Font size used: 146
# Processing image 436
# Font size used: 143
# Processing image 437
# Font size used: 90
# Processing image 438
# Warning: Font size reached minimum limit for image 438.
# Font size used: 50
# Processing image 439
# Font size used: 133
# Processing image 440
# Font size used: 61
# Processing image 441
# Font size used: 64
# Processing image 442
# Warning: Font size reached minimum limit for image 442.
# Font size used: 49
# Processing image 443
# Warning: Font size reached minimum limit for image 443.
# Font size used: 50
# Processing image 444
# Font size used: 57
# Processing image 445
# Font size used: 62
# Processing image 446
# Font size used: 96
# Processing image 447
# Warning: Font size reached minimum limit for image 447.
# Font size used: 50
# Processing image 448
# Warning: Font size reached minimum limit for image 448.
# Font size used: 49
# Processing image 449
# Font size used: 76
# Processing image 450
# Font size used: 57
# Processing image 451
# Warning: Font size reached minimum limit for image 451.
# Font size used: 50
# Processing image 452
# Font size used: 64
# Processing image 453
# Font size used: 101
# Processing image 454
# Warning: Font size reached minimum limit for image 454.
# Font size used: 50
# Processing image 455
# Font size used: 71
# Processing image 456
# Font size used: 71
# Processing image 457
# Font size used: 107
# Processing image 458
# Font size used: 112
# Processing image 459
# Font size used: 94
# Processing image 460
# Font size used: 70
# Processing image 461
# Warning: Font size reached minimum limit for image 461.
# Font size used: 50
# Processing image 462
# Font size used: 70
# Processing image 463
# Font size used: 122
# Processing image 464
# Font size used: 72
# Processing image 465
# Font size used: 73
# Processing image 466
# Warning: Font size reached minimum limit for image 466.
# Font size used: 50
# Processing image 467
# Font size used: 56
# Processing image 468
# Font size used: 72
# Processing image 469
# Font size used: 54
# Processing image 470
# Font size used: 73
# Processing image 471
# Font size used: 126
# Processing image 472
# Font size used: 69
# Processing image 473
# Font size used: 120
# Processing image 474
# Warning: Font size reached minimum limit for image 474.
# Font size used: 50
# Processing image 475
# Font size used: 108
# Processing image 476
# Font size used: 105
# Processing image 477
# Warning: Font size reached minimum limit for image 477.
# Font size used: 50
# Processing image 478
# Font size used: 114
# Processing image 479
# Warning: Font size reached minimum limit for image 479.
# Font size used: 50
# Processing image 480
# Warning: Font size reached minimum limit for image 480.
# Font size used: 50
# Processing image 481
# Font size used: 138
# Processing image 482
# Font size used: 52
# Processing image 483
# Font size used: 83
# Processing image 484
# Font size used: 100
# Processing image 485
# Font size used: 137
# Processing image 486
# Font size used: 86
# Processing image 487
# Font size used: 88
# Processing image 488
# Warning: Font size reached minimum limit for image 488.
# Font size used: 50
# Processing image 489
# Font size used: 116
# Processing image 490
# Font size used: 65
# Processing image 491
# Font size used: 86
# Processing image 492
# Font size used: 145
# Processing image 493
# Font size used: 103
# Processing image 494
# Font size used: 81
# Processing image 495
# Font size used: 58
# Processing image 496
# Font size used: 72
# Processing image 497
# Font size used: 67
# Processing image 498
# Font size used: 69
# Processing image 499
# Font size used: 82
# Processing image 500
# Font size used: 63

# %% [markdown]
# ##### Option 3: Add Downloaded Transparent Logo as Watermark in Property Image

# %%
# Python list of cleaned-up names
real_estate_companies = [
    "5R Prime Properties",
    "650 Homes",
    "8990 Holdings, Inc.",
    "A Brown Company, Inc.",
    "ACM Homes Development Corp",
    "AboitizLand",
    "Active Group",
    "Aeon Luxe Properties Inc",
    "Agan Land Corp",
    "Al-Khor Dynamic Builders Inc.",
    "Alpina Heights Properties Corporation",
    "Alveo Land Corp.",
    "Amaia Land Corp.",
    "Anchor Land Holdings Inc",
    "Antel Land Holdings",
    "Apec Homes",
    "Arthaland",
    "Aseana Residential Holdings Corp.",
    "Asian Land Strategies Corporation",
    "Astranniquin Corporation",
    "Avida Land Corp.",
    "Axeia Development Corp",
    "Ayala Land Premier",
    "BESCO Clark Philippines Group of Companies, Corporation",
    "BJS Development Corporation",
    "Banff Realty %26 Development Corporation",
    "Bella Vita Land Corp",
    "Bellefonte Properties",
    "Bigpat Development",
    "Bilkenn Corporation",
    "Bluhomes",
    "Borland Development Corporation",
    "Breightonland",
    "Bria Homes",
    "Brittany Corporation",
    "C-5 Mansions Development Corporation",
    "CDC Holdings, Inc.",
    "CLS Properties Inc.",
    "COHO by Vista Land",
    "Calmar Land",
    "Camella Homes",
    "Camella Manors",
    "Cathay Land",
    "Cebu Land Masters, Inc.",
    "Central Country Estate Inc.",
    "Century Nuliv",
    "Chan Toei Properties",
    "Charles Builders Incorporated",
    "Citiglobal Realty %26 Development, Inc.",
    "Ciudades Development Corporation",
    "Clairmont Realty and Development Corporation",
    "Crown Asia",
    "DDC Land, Inc.",
    "DMCI Homes",
    "Damosa Land, Inc.",
    "DataLand Inc.",
    "Demeterland",
    "Dolmar Property Ventures, Inc.",
    "Don Tim Development Corp",
    "Double Dragon Properties Corporation",
    "Duraville Realty and Development Corp",
    "Duros Land Properties Inc",
    "ELM Land Inc",
    "Ecoglobal Development Corporation",
    "Elanvital Enclaves",
    "Empire East",
    "Enduraland Development Corporation",
    "Euro Tower International Inc.",
    "F.S Dulalia Realty",
    "Famtech Properties, Inc.",
    "Federal Land Inc",
    "Fiesta Communities inc",
    "Filigree",
    "Filinvest Land",
    "Firebird Holdings Corporation",
    "First Georgetown Ventures Inc.",
    "Fortune Real Properties",
    "G-Land Property %26 Development Corporation",
    "Geo Estate Development Corporation",
    "Global-Estate Resorts Inc.",
    "Golden Bay Landholdings",
    "Golden Home Realty Development Inc.",
    "Golden Tiger Realty %26 Properties, Corp.",
    "Golden Topper",
    "Goldstar Realty and Development Corporation",
    "GoshenLand",
    "Grand Taipan Land",
    "Green Island International Investments %26 Development Corporation",
    "Greenfield Development Corporation",
    "Greentech Development Corporation",
    "HTLand Inc.",
    "HausTalk, Inc.",
    "Hausland Development Corporation",
    "Hestia Properties and Development Corporation",
    "Homemark Inc.",
    "Honeycomb Builders Inc.",
    "Horizon Land Property Development Corp",
    "Imperial Homes Corporation",
    "Isoc Land",
    "Italpinas Development Corp",
    "Jackstone Properties Inc",
    "Jenson Land and Realty Development Corp.",
    "Keyland Corporation",
    "Kommuno Properties",
    "Landco Pacific Corporation",
    "Landisco Corp.",
    "Lessandra",
    "Lica Land",
    "Livingsprings Communitites Inc.",
    "Lumina Homes",
    "Lynville Land Development Corp",
    "Makati City Subway, Inc.",
    "Malveda Properties Development Corporation",
    "Maria Luisa Properties",
    "Megapines Realty %26 Development Corp.",
    "Megaworld Corporation",
    "Metrostar Realty Development Inc.",
    "Metrosummit Realty and Construction Corporation",
    "Moldex Realty, Inc.",
    "Montana Golden Real Estate Developer Company Inc",
    "MyCitihomes",
    "Myvan Properties %26 Development Inc.",
    "Nabaja Land Corporation",
    "New San Jose Builders Inc",
    "NewBeginnings Inc.",
    "Next Asia Homes",
    "Noble Land Development Corp",
    "Norheast Land Development Inc.",
    "Ortigas Land",
    "Ovialand",
    "P. A Properties Hankyu Hanshin",
    "P.A Properties",
    "PDB Properties Inc.",
    "PH1 World",
    "PIK",
    "Pabahay Equity Ventures Inc",
    "Pacifica Homes Development Corporation",
    "Philippine Realty %26 Holdings Corp",
    "Philippines Estate Corporation",
    "Phinma",
    "Phirst Park Homes",
    "Picar Development Inc.",
    "Plus Homes (Megawide)",
    "PonteFino Estates Creative Hotel Concepts, Inc.",
    "Priland Development Corporation",
    "Primary Homes Incorporated",
    "Prime Homes",
    "Primeworld Land Holdings Inc.",
    "Prince Jun Development Corporation",
    "Property of Friends and Company, Inc.",
    "Pueblo De Oro Development Corporation",
    "Pueblo de Panay Inc",
    "R Land Development Inc",
    "RCD Land Inc",
    "RHK Land Corporation",
    "RLC Residences",
    "Rafeli Realty %26 Development Corporation",
    "Red Oak Properties, Inc",
    "Reignwood Development Corporation",
    "Robinsons Homes",
    "Rockavilla Realty %26 Development Corporation",
    "Rockwell Land Corporation",
    "Roxaco Land Corporation",
    "Royal Properties, Inc.",
    "SM Development Corporation (SMDC)",
    "SOC Land Development Corporation",
    "SP Land Inc.",
    "ST. Felisse Realty and Development Corporation",
    "Shang Properties Inc",
    "Shang Robinson Properties Inc.",
    "Solanaland Development Inc.",
    "Solar Resources Inc",
    "Sta. Lucia Land Inc.",
    "Stateland, Inc.",
    "Summerhills Home Development Corporation",
    "Suntrust Properties, Inc.",
    "Sunwealth Land Development Corporation",
    "Taft Properties Inc.",
    "Taylormade Construction and Realty Corp.",
    "The Catanauan Cove Corp.",
    "The Estate Makati",
    "The Regalia Group Corp.",
    "Top Coastal Bay Realty Corporation",
    "Torre Lorenzo Development Corporation",
    "TransAsia Construction Development Corporation",
    "Transphil Real Estate Development Corp",
    "University Home",
    "Vanillascape Land Corporation",
    "Victor Consunji Development Corporation",
    "Vista Estates",
    "Vista Residences",
    "Wee Community Developers Inc.",
    "Worldwide Central Properties"
]

# Function to find the index of a logo name
def find_logo_index(name):
    try:
        return real_estate_companies.index(name)
    except ValueError:
        return random.randint(1, 193)

# Example usage
logo_name = "Camella Homes"
index = find_logo_index(logo_name)
print(f"The index of '{logo_name}' is: {index}")
# Out:
# The index of 'Camella Homes' is: 40

# %%
import os

def find_exact_filename(directory, number):
  """Finds the exact filename matching the given number.

  Args:
    directory: The directory to search.
    number: The number to match in the filename.

  Returns:
    The filename if found, otherwise None.
  """

  for filename in os.listdir(directory):
    if filename.startswith(f"image_{number}") and filename.endswith((".png", ".jpg")):
      return filename
  return None

# Example usage:
directory_path = r"C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos"
number_to_find = 5

filename = find_exact_filename(directory_path, 5)
if filename:
  print(f"Found file: {filename}")
else:
  print(f"File 'image_{number_to_find}' not found.")
# Out:
# Found file: image_5.png

# %% [markdown]
# ##### Adds the transparent logo watermark in property image

# %%
import requests
from PIL import Image
from io import BytesIO
import random, os

def download_and_watermark_images(image_urls, logo_names, logos_dir, output_dir, transparency=0.7):
    """Downloads images and adds a transparent watermark with random placement.

    Args:
        image_urls: A list of image URLs.
        logo_urls: A list of logo URLs, each corresponding to an image in image_urls.
        logos_dir: The directory to find the logo images.
        output_dir: The directory to save the watermarked images.
        transparency: The transparency level for the watermark logo (0 to 1).
    """
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for index, (image_url, logo_name) in enumerate(zip(image_urls, logo_names)):
        # Download and open each image
        image = Image.open(BytesIO(requests.get(image_url).content)).convert("RGBA")
        
        # find index of logo
        index = find_logo_index(logo_name)
        # use index to find the logo in the logos folder
        logo_filename = find_exact_filename(logos_dir, index)
        # Construct the full path to the image
        logo_path = os.path.join(logos_dir, logo_filename)

        # Open the image
        with Image.open(logo_path) as logo_image:
            # Get original width and height
            width, height = image.size

            # Calculate the aspect ratio
            aspect_ratio = width / height

            # Randomly choose a new size within the specified range
            new_size = random.randint(150, 400)

            # Determine the new height based on the chosen size and aspect ratio
            new_height = int(new_size / aspect_ratio)

            # Ensure the new height is within the specified range
            new_height = min(100, max(400, new_height))

            # Calculate the new width based on the new height and aspect ratio
            new_width = int(new_height * aspect_ratio)

            # Resize the image
            logo = logo_image.resize((new_width, new_height), Image.LANCZOS)


            # Randomly place the watermark within the image (fix for negative width)
            image_width, image_height = image.size
            watermark_width, watermark_height = logo.size
            max_x_position = image_width - watermark_width  # Maximum valid X position
            x = random.randint(0, max_x_position)  # Random X within valid range
            y = random.randint(0, image_height - watermark_height)


            # Create a new image with the watermark overlay
            watermark_image = image.copy()
            watermark_image.paste(logo, (x, y), logo)  # Using logo as the transparency mask

            # Save the watermarked image in JPEG format (or PNG if transparency is required)
            watermark_filename = f"watermarked_image_{index}.jpg"
            watermark_image.convert("RGB").save(os.path.join(output_dir, watermark_filename), "JPEG")

# Example usage
image_urls = [
    "https://api.omh.app/store/picture/a9c0f92e-1479-48fc-a212-e63ce9692723",
    "https://api.omh.app/store/picture/695f3135-3706-4800-af3d-d662051dbf09",
    # ... more image URLs
]
logo_names = [
    "Vista Estates",
    "Vista Residences",
    # ... more logo names
]
logos_dir = r"C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos"
output_dir = "watermarked_images/transparent_logo_watermark"

download_and_watermark_images(image_urls, logo_names, logos_dir, output_dir)

# %% [markdown]
# ##### Adds the transparent logo on a high contrasting background in the property image

# %%
import requests
from PIL import Image, ImageStat, ImageEnhance
from io import BytesIO
import random, os

def calculate_brightness(image):
    """Calculates the brightness of an image."""
    grayscale = image.convert("L")  # Convert to grayscale
    stat = ImageStat.Stat(grayscale)
    return stat.mean[0]  # Return the mean brightness

def find_contrasting_position(image, logo, threshold=128):
    """
    Finds a position in the image where the logo has contrasting brightness.
    Args:
        image: The main image.
        logo: The logo image.
        threshold: Brightness difference threshold for contrast.
    Returns:
        (x, y): Top-left position for placing the logo.
    """
    image_width, image_height = image.size
    logo_width, logo_height = logo.size
    max_x_position = image_width - logo_width
    max_y_position = image_height - logo_height

    # Iterate to find a good position
    for _ in range(50):  # Try 50 random positions
        x = random.randint(0, max_x_position)
        y = random.randint(0, max_y_position)
        crop_box = (x, y, x + logo_width, y + logo_height)
        region = image.crop(crop_box)
        region_brightness = calculate_brightness(region)
        logo_brightness = calculate_brightness(logo)
        if abs(region_brightness - logo_brightness) >= threshold:
            return x, y
    return random.randint(0, max_x_position), random.randint(0, max_y_position)  # Fallback random position

def download_and_watermark_images(image_urls, logo_names, logos_dir, output_dir, transparency=0.7):
    """Downloads images and adds a transparent watermark with intelligent placement."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for i, (image_url, logo_name) in enumerate(zip(image_urls, logo_names)):
        count = i + 1
        print(count)
        image = Image.open(BytesIO(requests.get(image_url).content)).convert("RGBA")
        
        # Find the logo path
        index = find_logo_index(logo_name)
        print("Logo Index: "+str(index))
        logo_filename = find_exact_filename(logos_dir, index)
        print("Logo filename: "+logo_filename)
        logo_path = os.path.join(logos_dir, logo_filename)
        print("Logo path: "+logo_path)

        # Open the logo
        with Image.open(logo_path) as logo_image:
            logo_image = logo_image.convert("RGBA")
            
            # Adjust transparency of the logo
            alpha = logo_image.split()[3]
            alpha = ImageEnhance.Brightness(alpha).enhance(transparency)
            logo_image.putalpha(alpha)
            
            # Resize the logo
            logo_width = int(image.width * 0.2)  # Scale logo to 20% of image width
            logo_height = int(logo_width * logo_image.height / logo_image.width)
            logo_image = logo_image.resize((logo_width, logo_height), Image.LANCZOS)
            
            # Find contrasting position
            x, y = find_contrasting_position(image, logo_image)
            
            # Create a new image with the watermark
            watermarked_image = image.copy()
            watermarked_image.paste(logo_image, (x, y), logo_image)

            # Save the watermarked image
            output_path = os.path.join(output_dir, f"watermarked_image_{count}.jpg")
            print("Watermark Image: "+output_path)
            watermarked_image.convert("RGB").save(output_path, "JPEG")

# Example usage
test_image_urls = [
    "https://api.omh.app/store/picture/a9c0f92e-1479-48fc-a212-e63ce9692723",
    "https://api.omh.app/store/picture/695f3135-3706-4800-af3d-d662051dbf09",
    # ... more image URLs
]
test_logo_names = [
    "Vista Estates",
    "Vista Residences",
    # ... more logo names
]
logos_dir = r"C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos"
test_output_dir = "watermarked_images/transparent_logo_watermark"

download_and_watermark_images(test_image_urls, test_logo_names, logos_dir, test_output_dir)
# Out:
# 1
# Logo Index: 189
# Logo filename: image_189.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_189.png
# Watermark Image: watermarked_images/transparent_logo_watermark\watermarked_image_1.jpg
# 2
# Logo Index: 190
# Logo filename: image_190.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_190.png
# Watermark Image: watermarked_images/transparent_logo_watermark\watermarked_image_2.jpg

# %%
# Example usage
# paste absolute path of CSV file here:
csv_path = r"C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\dataset\watermark_data.csv"
start_index = 0  # Start from the nth row (index 0 is the first row)
end_index = 249    # Extract up to the nth row (exclusive)

image_urls, developers, logo_urls = extract_columns_from_csv(csv_path, start_index, end_index)

# Print the extracted variables (optional)
print("Image URLs:")
print(image_urls.tolist())  # Print as a list

print("\nDevelopers:")
print(developers.tolist())  # Print as a list

print("\nLogo URLs:")
print(logo_urls.tolist())  # Print as a list
# Out:
# Image URLs:
# ['https://api.omh.app/store/picture/2cd4ea3c-73f3-40ab-bef9-a5167c718093', 'https://api.omh.app/store/picture/9d62b678-ff95-4a70-9f9b-259e1d61303d', 'https://api.omh.app/store/picture/90a97cfe-6cb4-41cc-be53-e5318239e4a3', 'https://api.omh.app/store/picture/e929c64a-391b-4d30-878d-9b62c33d4536', 'https://api.omh.app/store/picture/7fa2242a-02bb-48b2-9ec3-2ba75c85ad33', 'https://api.omh.app/store/picture/bfec52e7-ed1d-4d6b-8aef-685de06bcf6b', 'https://api.omh.app/store/picture/4fe29d8b-3239-4021-ba05-78aa55221835', 'https://api.omh.app/store/picture/8724be09-bd74-4998-bf6e-8d4dcc8bd338', 'https://api.omh.app/store/picture/f4cbf625-5d65-4038-9641-5bcc5cb86924', 'https://api.omh.app/store/picture/bef4928a-b62d-4e6f-9963-24107179731f', 'https://api.omh.app/store/picture/a43cb1cf-d246-4760-a452-1d789b0d8962', 'https://api.omh.app/store/picture/0a028a9f-aea1-4e4e-81ea-9a3f427caf35', 'https://api.omh.app/store/picture/143fa19c-161c-45be-81cd-8b384ba2c3d4', 'https://api.omh.app/store/picture/43d44612-54e9-4720-b76f-3dd7b9e142da', 'https://api.omh.app/store/picture/f5b792bd-1dd4-479a-8fa0-ff60ad2f7f2b', 'https://api.omh.app/store/picture/e759077d-a456-4c3c-bc0b-36953eecaa44', 'https://api.omh.app/store/picture/4e26228e-5882-454c-96d6-bda4faa2eac6', 'https://api.omh.app/store/picture/6eb88df9-6f9c-45cc-aff3-aab7e16c8407', 'https://api.omh.app/store/picture/f1a8c435-ae11-49d3-bf99-6c5412466625', 'https://api.omh.app/store/picture/770c6229-e7a9-4ac4-a168-b6de01269dfb', 'https://api.omh.app/store/picture/03a02cb5-1c40-4ccf-ac1c-3045639b3b9c', 'https://api.omh.app/store/picture/1ced4d11-42fb-4824-855e-686ffef8c3fa', 'https://api.omh.app/store/picture/3a292dc4-2c7c-40fb-b19a-4ef4bd0b59ed', 'https://api.omh.app/store/picture/6784c8db-2186-4f88-b6bb-80a8af74a82e', 'https://api.omh.app/store/picture/4e16c37f-db38-448b-91fa-c0daa2db1df2', 'https://api.omh.app/store/picture/5eacb907-4122-4e7e-aab7-9517816e981f', 'https://api.omh.app/store/picture/12f14361-e275-48ec-82f6-88fe03433ed5', 'https://api.omh.app/store/picture/5fbc7721-fbcd-44d1-82cb-8aa388d767b7', 'https://api.omh.app/store/picture/5a028bd1-acf2-4722-8069-bc7ac9353d24', 'https://api.omh.app/store/picture/3470f627-9fed-4cd7-a008-4d93796db57a', 'https://api.omh.app/store/picture/c1ca162b-1a74-4f15-a833-cdfd2e50093c', 'https://api.omh.app/store/picture/211c67d8-596a-41da-9cb1-f3711c01875e', 'https://api.omh.app/store/picture/cbda9830-f096-443b-b127-3c26b38ed1b5', 'https://api.omh.app/store/picture/e36e681e-de9f-448d-bbc9-38ddb974c9f1', 'https://api.omh.app/store/picture/9005defd-2312-4ce5-bb28-54b187770eb1', 'https://api.omh.app/store/picture/9ae0c5cb-6e22-4479-b623-4f8c89fa1fcc', 'https://api.omh.app/store/picture/51761283-6446-4fab-bb91-63a67de280dc', 'https://api.omh.app/store/picture/3b7303bd-654b-414d-a2da-b2e74b6d22bf', 'https://api.omh.app/store/picture/560fd653-bc20-4d62-8ea5-8694c0d0d0ce', 'https://api.omh.app/store/picture/15e44a64-f1b5-4653-ab3c-af5409aab580', 'https://api.omh.app/store/picture/b41d716d-f130-4da1-89f6-3f1b752d3542', 'https://api.omh.app/store/picture/f2190d7b-53b8-446a-a789-ed926f4df4b4', 'https://api.omh.app/store/picture/4557195c-e315-48ff-bd9d-362dd9063489', 'https://api.omh.app/store/picture/f960b194-66dd-4dc1-9664-7ee9926bb565', 'https://api.omh.app/store/picture/681dbc36-1974-4378-baad-5adf03afd8dd', 'https://api.omh.app/store/picture/47b92971-864b-4f11-b770-f961e0e8d2e5', 'https://api.omh.app/store/picture/0c7b5a46-1651-4d41-bd90-d4c4e35caef5', 'https://api.omh.app/store/picture/4bd505b0-6305-43f5-a5c2-791bb052f85f', 'https://api.omh.app/store/picture/047a1267-2044-4cf9-8e9a-76c0d1d2dc95', 'https://api.omh.app/store/picture/07e991d9-751d-4f1f-a311-587819356f66', 'https://api.omh.app/store/picture/bf41ad92-9774-4d78-bc15-e1b6e8271a2c', 'https://api.omh.app/store/picture/868d8912-4400-43f7-8acb-55005e44c7d0', 'https://api.omh.app/store/picture/9dedbfcb-d256-49bd-ae02-e58d0d5a1e01', 'https://api.omh.app/store/picture/857ea4e4-5096-45ad-b716-ff48c54367c9', 'ht ...
#
# Developers:
# ['State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'State Properties Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Pacifica Homes Development Corporation', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Breightonland', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Transphil Real Estate Development Corp', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Apec Homes', 'Elanvital Enclaves', 'Elanvital Enclaves', 'Elanvital Enclaves', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'Norheast Land Development Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'Luna-Dolores-Milagro Road,Ormoc,Leyte,6541', 'Luna-Dolores-Milagro Road,Ormoc,Leyte,6541', 'Luna-Dolores-Milagro Road,Ormoc,Leyte,6541', 'Luna-Dolores-Milagro Road,Ormoc,Leyte,6541', 'Luna-Dolores-Milagro Road,Ormoc,Leyte,6541', 'Luna-Dolores-Milagro Road,Ormoc,Leyte,6541', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'CLS Properties Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'A Brown Company,Inc.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp.', 'Amaia Land Corp ...
#
# Logo URLs:
# ['https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/db0aa5ac-67c5-4ce1-87b0-ea8680738783', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/2119fbc9-edaf-4b5f-a96b-6e04e2b51507', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'https://api.omh.app/store/picture/7b76b1e0-2532-4f37-9d0b-49cf4ce3e426', 'ht ...

# %%
output_dir = "watermarked_images/b"
download_and_watermark_images(image_urls, developers, logos_dir, output_dir)
# Out:
# 1
# Logo Index: 4
# Logo filename: image_4.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_4.png
# Watermark Image: watermarked_images/b\watermarked_image_1.jpg
# 2
# Logo Index: 181
# Logo filename: image_181.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_181.png
# Watermark Image: watermarked_images/b\watermarked_image_2.jpg
# 3
# Logo Index: 146
# Logo filename: image_146.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_146.png
# Watermark Image: watermarked_images/b\watermarked_image_3.jpg
# 4
# Logo Index: 38
# Logo filename: image_38.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_38.png
# Watermark Image: watermarked_images/b\watermarked_image_4.jpg
# 5
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_5.jpg
# 6
# Logo Index: 112
# Logo filename: image_112.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_112.png
# Watermark Image: watermarked_images/b\watermarked_image_6.jpg
# 7
# Logo Index: 79
# Logo filename: image_79.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_79.jpg
# Watermark Image: watermarked_images/b\watermarked_image_7.jpg
# 8
# Logo Index: 58
# Logo filename: image_58.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_58.jpg
# Watermark Image: watermarked_images/b\watermarked_image_8.jpg
# 9
# Logo Index: 147
# Logo filename: image_147.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_147.png
# Watermark Image: watermarked_images/b\watermarked_image_9.jpg
# 10
# Logo Index: 87
# Logo filename: image_87.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_87.jpg
# Watermark Image: watermarked_images/b\watermarked_image_10.jpg
# 11
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_11.jpg
# 12
# Logo Index: 94
# Logo filename: image_94.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_94.png
# Watermark Image: watermarked_images/b\watermarked_image_12.jpg
# 13
# Logo Index: 69
# Logo filename: image_69.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_69.png
# Watermark Image: watermarked_images/b\watermarked_image_13.jpg
# 14
# Logo Index: 191
# Logo filename: image_191.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_191.png
# Watermark Image: watermarked_images/b\watermarked_image_14.jpg
# 15
# Logo Index: 87
# Logo filename: image_87.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_87.jpg
# Watermark Image: watermarked_images/b\watermarked_image_15.jpg
# 16
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_16.jpg
# 17
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_17.jpg
# 18
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_18.jpg
# 19
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_19.jpg
# 20
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_20.jpg
# 21
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_21.jpg
# 22
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_22.jpg
# 23
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_23.jpg
# 24
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_24.jpg
# 25
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_25.jpg
# 26
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_26.jpg
# 27
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_27.jpg
# 28
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_28.jpg
# 29
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_29.jpg
# 30
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_30.jpg
# 31
# Logo Index: 136
# Logo filename: image_136.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_136.png
# Watermark Image: watermarked_images/b\watermarked_image_31.jpg
# 32
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_32.jpg
# 33
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_33.jpg
# 34
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_34.jpg
# 35
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_35.jpg
# 36
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_36.jpg
# 37
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_37.jpg
# 38
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_38.jpg
# 39
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_39.jpg
# 40
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_40.jpg
# 41
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_41.jpg
# 42
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_42.jpg
# 43
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_43.jpg
# 44
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_44.jpg
# 45
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_45.jpg
# 46
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_46.jpg
# 47
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_47.jpg
# 48
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_48.jpg
# 49
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_49.jpg
# 50
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_50.jpg
# 51
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_51.jpg
# 52
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_52.jpg
# 53
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_53.jpg
# 54
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_54.jpg
# 55
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_55.jpg
# 56
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_56.jpg
# 57
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_57.jpg
# 58
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_58.jpg
# 59
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_59.jpg
# 60
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_60.jpg
# 61
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_61.jpg
# 62
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_62.jpg
# 63
# Logo Index: 185
# Logo filename: image_185.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_185.png
# Watermark Image: watermarked_images/b\watermarked_image_63.jpg
# 64
# Logo Index: 185
# Logo filename: image_185.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_185.png
# Watermark Image: watermarked_images/b\watermarked_image_64.jpg
# 65
# Logo Index: 185
# Logo filename: image_185.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_185.png
# Watermark Image: watermarked_images/b\watermarked_image_65.jpg
# 66
# Logo Index: 185
# Logo filename: image_185.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_185.png
# Watermark Image: watermarked_images/b\watermarked_image_66.jpg
# 67
# Logo Index: 185
# Logo filename: image_185.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_185.png
# Watermark Image: watermarked_images/b\watermarked_image_67.jpg
# 68
# Logo Index: 185
# Logo filename: image_185.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_185.png
# Watermark Image: watermarked_images/b\watermarked_image_68.jpg
# 69
# Logo Index: 185
# Logo filename: image_185.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_185.png
# Watermark Image: watermarked_images/b\watermarked_image_69.jpg
# 70
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_70.jpg
# 71
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_71.jpg
# 72
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_72.jpg
# 73
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_73.jpg
# 74
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_74.jpg
# 75
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_75.jpg
# 76
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_76.jpg
# 77
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_77.jpg
# 78
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_78.jpg
# 79
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_79.jpg
# 80
# Logo Index: 64
# Logo filename: image_64.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_64.jpg
# Watermark Image: watermarked_images/b\watermarked_image_80.jpg
# 81
# Logo Index: 64
# Logo filename: image_64.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_64.jpg
# Watermark Image: watermarked_images/b\watermarked_image_81.jpg
# 82
# Logo Index: 64
# Logo filename: image_64.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_64.jpg
# Watermark Image: watermarked_images/b\watermarked_image_82.jpg
# 83
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_83.jpg
# 84
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_84.jpg
# 85
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_85.jpg
# 86
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_86.jpg
# 87
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_87.jpg
# 88
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_88.jpg
# 89
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_89.jpg
# 90
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_90.jpg
# 91
# Logo Index: 127
# Logo filename: image_127.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_127.png
# Watermark Image: watermarked_images/b\watermarked_image_91.jpg
# 92
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_92.jpg
# 93
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_93.jpg
# 94
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_94.jpg
# 95
# Logo Index: 97
# Logo filename: image_97.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_97.png
# Watermark Image: watermarked_images/b\watermarked_image_95.jpg
# 96
# Logo Index: 142
# Logo filename: image_142.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_142.png
# Watermark Image: watermarked_images/b\watermarked_image_96.jpg
# 97
# Logo Index: 25
# Logo filename: image_25.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_25.png
# Watermark Image: watermarked_images/b\watermarked_image_97.jpg
# 98
# Logo Index: 182
# Logo filename: image_182.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_182.png
# Watermark Image: watermarked_images/b\watermarked_image_98.jpg
# 99
# Logo Index: 161
# Logo filename: image_161.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_161.png
# Watermark Image: watermarked_images/b\watermarked_image_99.jpg
# 100
# Logo Index: 139
# Logo filename: image_139.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_139.png
# Watermark Image: watermarked_images/b\watermarked_image_100.jpg
# 101
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_101.jpg
# 102
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_102.jpg
# 103
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_103.jpg
# 104
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_104.jpg
# 105
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_105.jpg
# 106
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_106.jpg
# 107
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_107.jpg
# 108
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_108.jpg
# 109
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_109.jpg
# 110
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_110.jpg
# 111
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_111.jpg
# 112
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_112.jpg
# 113
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_113.jpg
# 114
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_114.jpg
# 115
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_115.jpg
# 116
# Logo Index: 31
# Logo filename: image_31.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_31.png
# Watermark Image: watermarked_images/b\watermarked_image_116.jpg
# 117
# Logo Index: 15
# Logo filename: image_15.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_15.png
# Watermark Image: watermarked_images/b\watermarked_image_117.jpg
# 118
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_118.jpg
# 119
# Logo Index: 142
# Logo filename: image_142.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_142.png
# Watermark Image: watermarked_images/b\watermarked_image_119.jpg
# 120
# Logo Index: 182
# Logo filename: image_182.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_182.png
# Watermark Image: watermarked_images/b\watermarked_image_120.jpg
# 121
# Logo Index: 64
# Logo filename: image_64.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_64.jpg
# Watermark Image: watermarked_images/b\watermarked_image_121.jpg
# 122
# Logo Index: 41
# Logo filename: image_41.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_41.jpg
# Watermark Image: watermarked_images/b\watermarked_image_122.jpg
# 123
# Logo Index: 162
# Logo filename: image_162.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_162.png
# Watermark Image: watermarked_images/b\watermarked_image_123.jpg
# 124
# Logo Index: 25
# Logo filename: image_25.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_25.png
# Watermark Image: watermarked_images/b\watermarked_image_124.jpg
# 125
# Logo Index: 59
# Logo filename: image_59.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_59.png
# Watermark Image: watermarked_images/b\watermarked_image_125.jpg
# 126
# Logo Index: 80
# Logo filename: image_80.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_80.png
# Watermark Image: watermarked_images/b\watermarked_image_126.jpg
# 127
# Logo Index: 51
# Logo filename: image_51.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_51.png
# Watermark Image: watermarked_images/b\watermarked_image_127.jpg
# 128
# Logo Index: 132
# Logo filename: image_132.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_132.jpg
# Watermark Image: watermarked_images/b\watermarked_image_128.jpg
# 129
# Logo Index: 9
# Logo filename: image_9.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_9.png
# Watermark Image: watermarked_images/b\watermarked_image_129.jpg
# 130
# Logo Index: 162
# Logo filename: image_162.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_162.png
# Watermark Image: watermarked_images/b\watermarked_image_130.jpg
# 131
# Logo Index: 190
# Logo filename: image_190.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_190.png
# Watermark Image: watermarked_images/b\watermarked_image_131.jpg
# 132
# Logo Index: 174
# Logo filename: image_174.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_174.png
# Watermark Image: watermarked_images/b\watermarked_image_132.jpg
# 133
# Logo Index: 101
# Logo filename: image_101.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_101.png
# Watermark Image: watermarked_images/b\watermarked_image_133.jpg
# 134
# Logo Index: 37
# Logo filename: image_37.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_37.jpg
# Watermark Image: watermarked_images/b\watermarked_image_134.jpg
# 135
# Logo Index: 35
# Logo filename: image_35.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_35.png
# Watermark Image: watermarked_images/b\watermarked_image_135.jpg
# 136
# Logo Index: 101
# Logo filename: image_101.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_101.png
# Watermark Image: watermarked_images/b\watermarked_image_136.jpg
# 137
# Logo Index: 66
# Logo filename: image_66.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_66.png
# Watermark Image: watermarked_images/b\watermarked_image_137.jpg
# 138
# Logo Index: 120
# Logo filename: image_120.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_120.png
# Watermark Image: watermarked_images/b\watermarked_image_138.jpg
# 139
# Logo Index: 116
# Logo filename: image_116.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_116.png
# Watermark Image: watermarked_images/b\watermarked_image_139.jpg
# 140
# Logo Index: 151
# Logo filename: image_151.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_151.png
# Watermark Image: watermarked_images/b\watermarked_image_140.jpg
# 141
# Logo Index: 141
# Logo filename: image_141.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_141.png
# Watermark Image: watermarked_images/b\watermarked_image_141.jpg
# 142
# Logo Index: 24
# Logo filename: image_24.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_24.png
# Watermark Image: watermarked_images/b\watermarked_image_142.jpg
# 143
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_143.jpg
# 144
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_144.jpg
# 145
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_145.jpg
# 146
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_146.jpg
# 147
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_147.jpg
# 148
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_148.jpg
# 149
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_149.jpg
# 150
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_150.jpg
# 151
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_151.jpg
# 152
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_152.jpg
# 153
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_153.jpg
# 154
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_154.jpg
# 155
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_155.jpg
# 156
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_156.jpg
# 157
# Logo Index: 152
# Logo filename: image_152.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_152.jpg
# Watermark Image: watermarked_images/b\watermarked_image_157.jpg
# 158
# Logo Index: 152
# Logo filename: image_152.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_152.jpg
# Watermark Image: watermarked_images/b\watermarked_image_158.jpg
# 159
# Logo Index: 152
# Logo filename: image_152.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_152.jpg
# Watermark Image: watermarked_images/b\watermarked_image_159.jpg
# 160
# Logo Index: 152
# Logo filename: image_152.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_152.jpg
# Watermark Image: watermarked_images/b\watermarked_image_160.jpg
# 161
# Logo Index: 89
# Logo filename: image_89.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_89.png
# Watermark Image: watermarked_images/b\watermarked_image_161.jpg
# 162
# Logo Index: 89
# Logo filename: image_89.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_89.png
# Watermark Image: watermarked_images/b\watermarked_image_162.jpg
# 163
# Logo Index: 89
# Logo filename: image_89.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_89.png
# Watermark Image: watermarked_images/b\watermarked_image_163.jpg
# 164
# Logo Index: 89
# Logo filename: image_89.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_89.png
# Watermark Image: watermarked_images/b\watermarked_image_164.jpg
# 165
# Logo Index: 89
# Logo filename: image_89.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_89.png
# Watermark Image: watermarked_images/b\watermarked_image_165.jpg
# 166
# Logo Index: 89
# Logo filename: image_89.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_89.png
# Watermark Image: watermarked_images/b\watermarked_image_166.jpg
# 167
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_167.jpg
# 168
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_168.jpg
# 169
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_169.jpg
# 170
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_170.jpg
# 171
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_171.jpg
# 172
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_172.jpg
# 173
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_173.jpg
# 174
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_174.jpg
# 175
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_175.jpg
# 176
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_176.jpg
# 177
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_177.jpg
# 178
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_178.jpg
# 179
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_179.jpg
# 180
# Logo Index: 188
# Logo filename: image_188.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_188.png
# Watermark Image: watermarked_images/b\watermarked_image_180.jpg
# 181
# Logo Index: 188
# Logo filename: image_188.png
# ...
# Watermark Image: watermarked_images/b\watermarked_image_190.jpg
# 191
# Logo Index: 18
# Logo filename: image_18.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_18.png
# Watermark Image: watermarked_images/b\watermarked_image_191.jpg
# 192
# Logo Index: 66
# Logo filename: image_66.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_66.png
# Watermark Image: watermarked_images/b\watermarked_image_192.jpg
# 193
# Logo Index: 181
# Logo filename: image_181.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_181.png
# Watermark Image: watermarked_images/b\watermarked_image_193.jpg
# 194
# Logo Index: 12
# Logo filename: image_12.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_12.png
# Watermark Image: watermarked_images/b\watermarked_image_194.jpg
# 195
# Logo Index: 141
# Logo filename: image_141.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_141.png
# Watermark Image: watermarked_images/b\watermarked_image_195.jpg
# 196
# Logo Index: 93
# Logo filename: image_93.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_93.png
# Watermark Image: watermarked_images/b\watermarked_image_196.jpg
# 197
# Logo Index: 112
# Logo filename: image_112.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_112.png
# Watermark Image: watermarked_images/b\watermarked_image_197.jpg
# 198
# Logo Index: 165
# Logo filename: image_165.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_165.png
# Watermark Image: watermarked_images/b\watermarked_image_198.jpg
# 199
# Logo Index: 62
# Logo filename: image_62.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_62.png
# Watermark Image: watermarked_images/b\watermarked_image_199.jpg
# 200
# Logo Index: 131
# Logo filename: image_131.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_131.jpg
# Watermark Image: watermarked_images/b\watermarked_image_200.jpg
# 201
# Logo Index: 76
# Logo filename: image_76.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_76.png
# Watermark Image: watermarked_images/b\watermarked_image_201.jpg
# 202
# Logo Index: 121
# Logo filename: image_121.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_121.png
# Watermark Image: watermarked_images/b\watermarked_image_202.jpg
# 203
# Logo Index: 107
# Logo filename: image_107.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_107.jpg
# Watermark Image: watermarked_images/b\watermarked_image_203.jpg
# 204
# Logo Index: 6
# Logo filename: image_6.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_6.jpg
# Watermark Image: watermarked_images/b\watermarked_image_204.jpg
# 205
# Logo Index: 128
# Logo filename: image_128.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_128.jpg
# Watermark Image: watermarked_images/b\watermarked_image_205.jpg
# 206
# Logo Index: 121
# Logo filename: image_121.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_121.png
# Watermark Image: watermarked_images/b\watermarked_image_206.jpg
# 207
# Logo Index: 171
# Logo filename: image_171.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_171.png
# Watermark Image: watermarked_images/b\watermarked_image_207.jpg
# 208
# Logo Index: 6
# Logo filename: image_6.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_6.jpg
# Watermark Image: watermarked_images/b\watermarked_image_208.jpg
# 209
# Logo Index: 19
# Logo filename: image_19.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_19.png
# Watermark Image: watermarked_images/b\watermarked_image_209.jpg
# 210
# Logo Index: 42
# Logo filename: image_42.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_42.png
# Watermark Image: watermarked_images/b\watermarked_image_210.jpg
# 211
# Logo Index: 176
# Logo filename: image_176.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_176.jpg
# Watermark Image: watermarked_images/b\watermarked_image_211.jpg
# 212
# Logo Index: 149
# Logo filename: image_149.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_149.png
# Watermark Image: watermarked_images/b\watermarked_image_212.jpg
# 213
# Logo Index: 76
# Logo filename: image_76.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_76.png
# Watermark Image: watermarked_images/b\watermarked_image_213.jpg
# 214
# Logo Index: 119
# Logo filename: image_119.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_119.png
# Watermark Image: watermarked_images/b\watermarked_image_214.jpg
# 215
# Logo Index: 32
# Logo filename: image_32.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_32.png
# Watermark Image: watermarked_images/b\watermarked_image_215.jpg
# 216
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_216.jpg
# 217
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_217.jpg
# 218
# Logo Index: 123
# Logo filename: image_123.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_123.png
# Watermark Image: watermarked_images/b\watermarked_image_218.jpg
# 219
# Logo Index: 192
# Logo filename: image_192.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_192.png
# Watermark Image: watermarked_images/b\watermarked_image_219.jpg
# 220
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_220.jpg
# 221
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_221.jpg
# 222
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_222.jpg
# 223
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_223.jpg
# 224
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_224.jpg
# 225
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_225.jpg
# 226
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_226.jpg
# 227
# Logo Index: 39
# Logo filename: image_39.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_39.jpg
# Watermark Image: watermarked_images/b\watermarked_image_227.jpg
# 228
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_228.jpg
# 229
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_229.jpg
# 230
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_230.jpg
# 231
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_231.jpg
# 232
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_232.jpg
# 233
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_233.jpg
# 234
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_234.jpg
# 235
# Logo Index: 166
# Logo filename: image_166.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_166.png
# Watermark Image: watermarked_images/b\watermarked_image_235.jpg
# 236
# Logo Index: 143
# Logo filename: image_143.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_143.png
# Watermark Image: watermarked_images/b\watermarked_image_236.jpg
# 237
# Logo Index: 120
# Logo filename: image_120.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_120.png
# Watermark Image: watermarked_images/b\watermarked_image_237.jpg
# 238
# Logo Index: 81
# Logo filename: image_81.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_81.png
# Watermark Image: watermarked_images/b\watermarked_image_238.jpg
# 239
# Logo Index: 121
# Logo filename: image_121.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_121.png
# Watermark Image: watermarked_images/b\watermarked_image_239.jpg
# 240
# Logo Index: 49
# Logo filename: image_49.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_49.jpg
# Watermark Image: watermarked_images/b\watermarked_image_240.jpg
# 241
# Logo Index: 159
# Logo filename: image_159.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_159.jpg
# Watermark Image: watermarked_images/b\watermarked_image_241.jpg
# 242
# Logo Index: 170
# Logo filename: image_170.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_170.png
# Watermark Image: watermarked_images/b\watermarked_image_242.jpg
# 243
# Logo Index: 79
# Logo filename: image_79.jpg
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_79.jpg
# Watermark Image: watermarked_images/b\watermarked_image_243.jpg
# 244
# Logo Index: 46
# Logo filename: image_46.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_46.png
# Watermark Image: watermarked_images/b\watermarked_image_244.jpg
# 245
# Logo Index: 174
# Logo filename: image_174.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_174.png
# Watermark Image: watermarked_images/b\watermarked_image_245.jpg
# 246
# Logo Index: 62
# Logo filename: image_62.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_62.png
# Watermark Image: watermarked_images/b\watermarked_image_246.jpg
# 247
# Logo Index: 167
# Logo filename: image_167.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_167.png
# Watermark Image: watermarked_images/b\watermarked_image_247.jpg
# 248
# Logo Index: 167
# Logo filename: image_167.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_167.png
# Watermark Image: watermarked_images/b\watermarked_image_248.jpg
# 249
# Logo Index: 167
# Logo filename: image_167.png
# Logo path: C:\Users\lenovo\OneDrive\Documents\PROJECTS\ALT\Real-Estate-Image-Matching\data-scraping\watermark-scraper\1. scrape dataset\logos\image_167.png
# Watermark Image: watermarked_images/b\watermarked_image_249.jpg
